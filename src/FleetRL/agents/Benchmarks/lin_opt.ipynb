# %%
import datetime as dt
import numpy as np
import math
import matplotlib.pyplot as plt
from typing import Literal

from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3 import PPO, TD3
from stable_baselines3.common.vec_env import VecNormalize, SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env

from FleetRL.fleet_env.fleet_environment import FleetEnv

import pandas as pd
import pyomo.environ as pyo

# %%
# define parameters here for easier change
n_steps = 8600
n_episodes = 1
n_evs = 1
n_envs = 1
time_steps_per_hour = 4
use_case: str = "lmd"  # for file name
scenario: Literal["arb", "real"] = "arb"

# %%
env_kwargs = {"schedule_name": "lmd_sched_single_eval.csv",
              "building_name": "load_lmd.csv",
              "price_name": "spot_2021_new.csv",
              "tariff_name": "spot_2021_new_tariff.csv",
              "use_case": "lmd",
              "include_building": True,
              "include_pv": True,
              "time_picker": "static",
              "deg_emp": False,
              "include_price": True,
              "ignore_price_reward": False,
              "ignore_invalid_penalty": True,
              "ignore_overcharging_penalty": True,
              "ignore_overloading_penalty": False,
              "episode_length": n_steps,
              "normalize_in_env": False,
              "verbose": 0,
              "aux": True,
              "log_data": True,
              "calculate_degradation": True
              }

if scenario == "real":
    env_kwargs["spot_markup"] = 10
    env_kwargs["spot_mul"] = 1.5
    env_kwargs["feed_in_ded"] = 0.25
elif scenario == "arb":
    env_kwargs["spot_markup"] = 0
    env_kwargs["spot_mul"] = 1
    env_kwargs["feed_in_ded"] = 0

# %%
night_vec_env = make_vec_env(FleetEnv,
                             n_envs=n_envs,
                             vec_env_cls=SubprocVecEnv,
                             env_kwargs=env_kwargs)

# %%
night_norm_vec_env = VecNormalize(venv=night_vec_env,
                                  norm_obs=True,
                                  norm_reward=True,
                                  training=True,
                                  clip_reward=10.0)

# %%
env = FleetEnv(use_case=use_case,
               schedule_name=env_kwargs["schedule_name"],
               tariff_name=env_kwargs["tariff_name"],
               price_name=env_kwargs["price_name"],
               episode_length=n_steps,
               time_picker=env_kwargs["time_picker"],
               building_name=env_kwargs["building_name"])

# %%
# reading the input file as a pandas DataFrame
df: pd.DataFrame = env.db

# Extracting information from the df
ev_data = df["There"]
building_data = df["load"]  # building load in kW

if scenario == "arb":
    price_data = np.multiply(np.add(df["DELU"], env.ev_conf.fixed_markup), env.ev_conf.variable_multiplier) / 1000
    tariff_data = np.multiply(df["tariff"], 1-env.ev_conf.feed_in_deduction) / 1000
elif scenario == "real":
    price_data = np.multiply(np.add(df["DELU"], 0), 1) / 1000  # price in EUR/kWh
    tariff_data = np.multiply(np.add(df["DELU"], 0), 1) / 1000  # price in EUR/kWh

pv_data = df["pv"]  # pv power in kW
soc_on_return = df["SOC_on_return"]

battery_capacity = env.ev_conf.init_battery_cap  # EV batt size in kWh
p_trafo = env.load_calculation.grid_connection  # Transformer rating in kW

charging_eff = env.ev_conf.charging_eff  # charging losses
discharging_eff = env.ev_conf.discharging_eff  # discharging losses

init_soc = env.ev_conf.def_soc  # init SoC

evse_max_power = env.load_calculation.evse_max_power  # kW, max rating of the charger

# %%
# create pyomo model
model = pyo.ConcreteModel(name="sc_pyomo")

model.timestep = pyo.Set(initialize=range(len(df)))
model.time_batt = pyo.Set(initialize=range(0, len(df)+1))

# %%
# model parameters
model.building_load = pyo.Param(model.timestep, initialize={i: building_data[i] for i in range(len(df))})
model.pv = pyo.Param(model.timestep, initialize={i: pv_data[i] for i in range(len(df))})
model.ev_availability = pyo.Param(model.timestep, initialize={i: ev_data[i] for i in range(len(df))})
model.price = pyo.Param(model.timestep, initialize={i: price_data[i] for i in range(len(df))})
model.tariff = pyo.Param(model.timestep, initialize={i: tariff_data[i] for i in range(len(df))})

# %%
# decision variables
# this assumes only charging, I could also make bidirectional later
model.soc = pyo.Var(model.time_batt, bounds=(0, env.ev_conf.target_soc))
model.charging_signal = pyo.Var(model.timestep, within=pyo.NonNegativeReals, bounds=(0,1))
model.discharging_signal = pyo.Var(model.timestep, within=pyo.NonPositiveReals, bounds=(-1,0))
model.positive_action = pyo.Var(model.timestep, within=pyo.Binary)
model.used_pv = pyo.Var(model.timestep, within=pyo.NonNegativeReals)

# %%
def grid_limit(m, i):
    return ((m.charging_signal[i] + m.discharging_signal[i]) * evse_max_power
            + m.building_load[i] - m.pv[i] + m.used_pv[i]  <= p_trafo) # added the used_pv to trafo limit

# %%
def mutual_exclusivity_charging(m, i):
    return m.charging_signal[i] <= model.positive_action[i]

def mutual_exclusivity_discharging(m, i):
    return m.discharging_signal[i] >= (model.positive_action[i] - 1)

# %%
def pv_use(m, i):
    return m.used_pv[i] <= m.charging_signal[i] * evse_max_power

# %%
def pv_constraint(m, i):
    return m.used_pv[i] <= m.pv[i]

# %%
def no_charge_when_no_car(m, i):
    if m.ev_availability[i] == 0:
        return m.charging_signal[i] == 0
    else:
        return pyo.Constraint.Feasible

def no_discharge_when_no_car(m, i):
    if m.ev_availability[i] == 0:
        return m.discharging_signal[i] == 0
    else:
        return pyo.Constraint.Feasible

# %%
def soc_rules(m, i):
    #last time step
    if i == len(df)-1:
        return (m.soc[i+1]
                == m.soc[i] + (m.charging_signal[i]*charging_eff + m.discharging_signal[i])
                * evse_max_power * 1 / time_steps_per_hour / battery_capacity)

    # new arrival
    elif (m.ev_availability[i] == 0) and (m.ev_availability[i+1] == 1):
        return m.soc[i+1] == soc_on_return[i+1]

    # departure in next time step
    elif (m.ev_availability[i] == 1) and (m.ev_availability[i+1] == 0):
        return m.soc[i] == env.ev_conf.target_soc

    else:
        return pyo.Constraint.Feasible

# %%
def charging_dynamics(m, i):
    #last time step
    if i == len(df)-1:
        return (m.soc[i+1]
                == m.soc[i] + (m.charging_signal[i]*charging_eff + m.discharging_signal[i])
                * evse_max_power * 1 / time_steps_per_hour / battery_capacity)

    # charging
    if (m.ev_availability[i] == 1) and (m.ev_availability[i+1] == 1):
        return (m.soc[i+1]
                == m.soc[i] + (m.charging_signal[i]*charging_eff + m.discharging_signal[i])
                * evse_max_power * 1 / time_steps_per_hour / battery_capacity)

    elif (m.ev_availability[i] == 1) and (m.ev_availability[i+1] == 0):
        return m.soc[i+1] == 0

    elif m.ev_availability[i] == 0:
        return m.soc[i] == 0

    else:
        return pyo.Constraint.Feasible

# %%
def max_charging_limit(m, i):
    return m.charging_signal[i]*evse_max_power <= evse_max_power * ev_data[i]

def max_discharging_limit(m, i):
    return m.discharging_signal[i]*evse_max_power*-1 <= evse_max_power * ev_data[i]

# %%
def first_soc(m):
    return m.soc[0] == init_soc

# %%
# constraints
model.cs1 = pyo.Constraint(rule=first_soc)
model.cs2 = pyo.Constraint(model.timestep, rule=grid_limit)
model.cs3 = pyo.Constraint(model.timestep, rule=max_charging_limit)
model.cs4 = pyo.Constraint(model.timestep, rule=max_discharging_limit)
model.cs5 = pyo.Constraint(model.timestep, rule=soc_rules)
model.cs6 = pyo.Constraint(model.timestep, rule=charging_dynamics)
model.cs8 = pyo.Constraint(model.timestep, rule=mutual_exclusivity_charging)
model.cs9 = pyo.Constraint(model.timestep, rule=mutual_exclusivity_discharging)
model.cs10 = pyo.Constraint(model.timestep, rule=no_charge_when_no_car)
model.cs11 = pyo.Constraint(model.timestep, rule=no_discharge_when_no_car)
model.cs12 = pyo.Constraint(model.timestep, rule=pv_use)
model.cs13 = pyo.Constraint(model.timestep, rule=pv_constraint)

# %%
timestep_set = pyo.RangeSet(0, len(df)-1)

# %%
def obj_fun(m):
    return (sum([((m.charging_signal[i] * evse_max_power - m.used_pv[i]) / time_steps_per_hour) * m.price[i] +
                 ((m.discharging_signal[i] * evse_max_power * discharging_eff) / time_steps_per_hour) * m.tariff[i]
                 for i in m.timestep]))

model.obj = pyo.Objective(rule=obj_fun, sense=pyo.minimize)

# %%
opt = pyo.SolverFactory('glpk', keepfiles=True, tmpdir='./tmp_glpk/')
res = opt.solve(model, tee=True)
print(res)
# Out:
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --write /tmp/tmpiya1mfqr.glpk.raw --wglp /tmp/tmpb7qwotle.glpk.glp --cpxlp
#  /tmp/tmp88zvnrhf.pyomo.lp
# Reading problem data from '/tmp/tmp88zvnrhf.pyomo.lp'...
# /tmp/tmp88zvnrhf.pyomo.lp:1754126: warning: lower bound of variable 'x280952' redefined
# /tmp/tmp88zvnrhf.pyomo.lp:1754126: warning: upper bound of variable 'x280952' redefined
# 309210 rows, 175201 columns, 546201 non-zeros
# 35040 integer variables, all of which are binary
# 1789166 lines were read
# Writing problem data to '/tmp/tmpb7qwotle.glpk.glp'...
# 1521767 lines were written
# GLPK Integer Optimizer 5.0
# 309210 rows, 175201 columns, 546201 non-zeros
# 35040 integer variables, all of which are binary
# Preprocessing...
# 68349 rows, 88944 columns, 177265 non-zeros
# 20909 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  4.171e-02  max|aij| =  1.100e+01  ratio =  2.637e+02
# GM: min|aij| =  8.839e-01  max|aij| =  1.131e+00  ratio =  1.280e+00
# EQ: min|aij| =  7.827e-01  max|aij| =  1.000e+00  ratio =  1.278e+00
# 2N: min|aij| =  5.000e-01  max|aij| =  1.000e+00  ratio =  2.000e+00
# Constructing initial basis...
# Size of triangular part is 68348
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 68349 rows, 88944 columns, 177265 non-zeros
#       0: obj =   3.126942571e+02 inf =   6.265e+03 (5019)
#    2405: obj =   3.322306420e+02 inf =   4.187e+03 (4401) 18
# Perturbing LP to avoid stalling [2955]...
#    5109: obj =   3.857981973e+02 inf =   3.898e+03 (4344) 1
#    7586: obj =   4.331994990e+02 inf =   3.667e+03 (4215) 2
#   10148: obj =   4.761682341e+02 inf =   3.441e+03 (4023) 4
#   12233: obj =   5.075711008e+02 inf =   3.235e+03 (3869) 2
#   14110: obj =   5.445345490e+02 inf =   2.985e+03 (3694) 4
#   15855: obj =   5.836095423e+02 inf =   2.749e+03 (3548) 3
#   17671: obj =   6.179076915e+02 inf =   2.507e+03 (3396) 3
#   20054: obj =   6.505970764e+02 inf =   2.302e+03 (3253) 2
#   22398: obj =   6.611786180e+02 inf =   2.243e+03 (3214) 1
#   24791: obj =   6.638414809e+02 inf =   2.218e+03 (3195)
#   27247: obj =   6.639947932e+02 inf =   2.218e+03 (3194)
#   29828: obj =   8.945222890e+02 inf =   1.365e+03 (1904) 1
#   32413: obj =   1.339923008e+03 inf =   3.878e+02 (607) 1
#   33986: obj =   1.677290560e+03 inf =   6.870e-07 (0) 1
# * 36461: obj =   1.425462445e+03 inf =   5.110e-07 (21175) 3
# * 38714: obj =   1.308201359e+03 inf =   4.708e-07 (20173) 4
# * 40606: obj =   1.208403310e+03 inf =   4.404e-07 (19300) 3
# * 42169: obj =   1.134185313e+03 inf =   4.141e-07 (18112) 3
# * 44314: obj =   1.016529307e+03 inf =   3.396e-07 (16548) 6
# * 46074: obj =   9.028727216e+02 inf =   2.659e-07 (15637) 7
# * 47781: obj =   8.083126930e+02 inf =   2.183e-07 (13531) 6
# * 49679: obj =   7.049685363e+02 inf =   1.522e-07 (11700) 7
# * 51322: obj =   6.279585820e+02 inf =   1.500e-07 (11052) 7
# * 52936: obj =   5.612316308e+02 inf =   1.564e-07 (10352) 6
# * 54532: obj =   5.052053083e+02 inf =   1.521e-07 (9201) 7
# * 56062: obj =   4.573379959e+02 inf =   1.468e-07 (8270) 6
# * 57829: obj =   4.037488881e+02 inf =   1.468e-07 (7254) 8
# * 59774: obj =   3.604325004e+02 inf =   1.536e-07 (6112) 9
# * 61688: obj =   3.260658628e+02 inf =   1.431e-07 (4934) 9
# * 63626: obj =   3.050144573e+02 inf =   1.472e-07 (3574) 9
# * 65632: obj =   2.957045248e+02 inf =   1.501e-07 (2124) 9
# * 67557: obj =   2.920890049e+02 inf =   1.369e-07 (581) 8
# Removing LP perturbation [68293]...
# * 68293: obj =   2.917452052e+02 inf =   2.048e-13 (0) 5
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# + 68293: mip =     not found yet >=              -inf        (1; 0)
# + 68293: mip =     not found yet >=   2.917452052e+02        (2; 0)
# + 68294: mip =     not found yet >=   2.917620578e+02        (3; 0)
# + 68295: mip =     not found yet >=   2.917789104e+02        (4; 0)
# + 68297: mip =     not found yet >=   2.917957631e+02        (5; 0)
# + 68298: mip =     not found yet >=   2.918126157e+02        (6; 0)
# Time used: 66.1 secs.  Memory used: 183.9 Mb.
# + 68299: mip =     not found yet >=   2.918192462e+02        (7; 0)
# + 68301: mip =     not found yet >=   2.918258767e+02        (8; 0)
# + 68302: mip =     not found yet >=   2.918325072e+02        (9; 0)
# + 68303: mip =     not found yet >=   2.918391377e+02        (10; 0)
# + 68304: mip =     not found yet >=   2.918456308e+02        (11; 0)
# Time used: 137.8 secs.  Memory used: 184.0 Mb.
# + 68305: mip =     not found yet >=   2.918521238e+02        (12; 0)
# + 68307: mip =     not found yet >=   2.918601547e+02        (13; 0)
# + 68308: mip =     not found yet >=   2.918680357e+02        (14; 0)
# + 68309: mip =     not found yet >=   2.918764646e+02        (15; 0)
# + 68311: mip =     not found yet >=   2.918848935e+02        (16; 0)
# Time used: 203.9 secs.  Memory used: 184.0 Mb.
# + 68312: mip =     not found yet >=   2.918933224e+02        (17; 0)
# + 68314: mip =     not found yet >=   2.919017512e+02        (18; 0)
# + 68315: mip =     not found yet >=   2.919149476e+02        (19; 0)
# + 68316: mip =     not found yet >=   2.919281440e+02        (20; 0)
# + 68318: mip =     not found yet >=   2.919413404e+02        (21; 0)
# Time used: 267.7 secs.  Memory used: 184.0 Mb.
# + 68319: mip =     not found yet >=   2.919545368e+02        (22; 0)
# + 68321: mip =     not found yet >=   2.919657655e+02        (23; 0)
# + 68322: mip =     not found yet >=   2.919657655e+02        (24; 0)
# + 68323: mip =     not found yet >=   2.919657655e+02        (25; 0)
# + 68324: mip =     not found yet >=   2.919657655e+02        (26; 0)
# Time used: 337.1 secs.  Memory used: 184.0 Mb.
# + 68325: mip =     not found yet >=   2.919701339e+02        (27; 0)
# + 68327: mip =     not found yet >=   2.919745023e+02        (28; 0)
# + 68328: mip =     not found yet >=   2.919788707e+02        (29; 0)
# + 68329: mip =     not found yet >=   2.919832391e+02        (30; 0)
# + 68335: mip =     not found yet >=   2.919843032e+02        (31; 0)
# Time used: 406.3 secs.  Memory used: 184.0 Mb.
# + 68336: mip =     not found yet >=   2.919843032e+02        (32; 0)
# + 68337: mip =     not found yet >=   2.919843032e+02        (33; 0)
# + 68338: mip =     not found yet >=   2.919843032e+02        (34; 0)
# + 68339: mip =     not found yet >=   2.919885279e+02        (35; 0)
# + 68341: mip =     not found yet >=   2.919927526e+02        (36; 0)
# Time used: 470.9 secs.  Memory used: 184.0 Mb.
# + 68343: mip =     not found yet >=   2.919969773e+02        (37; 0)
# + 68345: mip =     not found yet >=   2.920012019e+02        (38; 0)
# + 68346: mip =     not found yet >=   2.920012019e+02        (39; 0)
# + 68348: mip =     not found yet >=   2.920274777e+02        (40; 0)
# + 68351: mip =     not found yet >=   2.920537535e+02        (41; 0)
# Time used: 535.0 secs.  Memory used: 184.0 Mb.
# + 68355: mip =     not found yet >=   2.920800292e+02        (42; 0)
# + 68356: mip =     not found yet >=   2.920800292e+02        (43; 0)
# + 68357: mip =     not found yet >=   2.920800292e+02        (44; 0)
# + 68358: mip =     not found yet >=   2.920800292e+02        (45; 0)
# + 68359: mip =     not found yet >=   2.920800292e+02        (46; 0)
# Time used: 605.7 secs.  Memory used: 184.0 Mb.
# + 68360: mip =     not found yet >=   2.920800292e+02        (47; 0)
# + 68361: mip =     not found yet >=   2.920800292e+02        (48; 0)
# + 68362: mip =     not found yet >=   2.920800292e+02        (49; 0)
# + 68363: mip =     not found yet >=   2.920800292e+02        (50; 0)
# + 68364: mip =     not found yet >=   2.920800292e+02        (51; 0)
# Time used: 676.1 secs.  Memory used: 184.0 Mb.
# + 68365: mip =     not found yet >=   2.920800292e+02        (52; 0)
# + 68366: mip =     not found yet >=   2.920800292e+02        (53; 0)
# + 68367: mip =     not found yet >=   2.920800292e+02        (54; 0)
# + 68368: mip =     not found yet >=   2.920800292e+02        (55; 0)
# + 68369: mip =     not found yet >=   2.920800292e+02        (56; 0)
# Time used: 744.9 secs.  Memory used: 184.0 Mb.
# + 68370: mip =     not found yet >=   2.920800292e+02        (57; 0)
# + 68371: mip =     not found yet >=   2.920800292e+02        (58; 0)
# + 68372: mip =     not found yet >=   2.920800292e+02        (59; 0)
# + 68373: mip =     not found yet >=   2.920800292e+02        (60; 0)
# + 68374: mip =     not found yet >=   2.920800292e+02        (61; 0)
# Time used: 810.5 secs.  Memory used: 184.0 Mb.
# + 68375: mip =     not found yet >=   2.920800292e+02        (62; 0)
# + 68382: mip =     not found yet >=   2.920811484e+02        (63; 0)
# + 68384: mip =     not found yet >=   2.920811484e+02        (64; 0)
# + 68386: mip =     not found yet >=   2.920811484e+02        (65; 0)
# + 68392: mip =     not found yet >=   2.920837528e+02        (66; 0)
# Time used: 877.4 secs.  Memory used: 184.0 Mb.
# + 68393: mip =     not found yet >=   2.920837528e+02        (67; 0)
# + 68396: mip =     not found yet >=   2.920888952e+02        (68; 0)
# + 68398: mip =     not found yet >=   2.920940376e+02        (69; 0)
# + 68402: mip =     not found yet >=   2.920991801e+02        (70; 0)
# + 68404: mip =     not found yet >=   2.921173339e+02        (71; 0)
# Time used: 945.6 secs.  Memory used: 184.0 Mb.
# + 68406: mip =     not found yet >=   2.921303452e+02        (72; 0)
# + 68407: mip =     not found yet >=   2.921433566e+02        (73; 0)
# + 68408: mip =     not found yet >=   2.921563679e+02        (74; 0)
# + 68409: mip =     not found yet >=   2.921563679e+02        (75; 0)
# Time used: 1007.1 secs.  Memory used: 184.0 Mb.
# + 68410: mip =     not found yet >=   2.921614951e+02        (76; 0)
# + 68412: mip =     not found yet >=   2.921614951e+02        (77; 0)
# + 68414: mip =     not found yet >=   2.921614951e+02        (78; 0)
# + 68416: mip =     not found yet >=   2.921614951e+02        (79; 0)
# Time used: 1076.2 secs.  Memory used: 184.0 Mb.
# + 68421: mip =     not found yet >=   2.921617578e+02        (80; 0)
# + 68422: mip =     not found yet >=   2.921670372e+02        (81; 0)
# + 68424: mip =     not found yet >=   2.921723165e+02        (82; 0)
# + 68425: mip =     not found yet >=   2.921723165e+02        (83; 0)
# + 68426: mip =     not found yet >=   2.921723165e+02        (84; 0)
# Time used: 1139.9 secs.  Memory used: 184.0 Mb.
# + 68427: mip =     not found yet >=   2.921723165e+02        (85; 0)
# + 68428: mip =     not found yet >=   2.921723165e+02        (86; 0)
# + 68429: mip =     not found yet >=   2.922076250e+02        (87; 0)
# + 68430: mip =     not found yet >=   2.922339654e+02        (88; 0)
# + 68432: mip =     not found yet >=   2.922339654e+02        (89; 0)
# Time used: 1204.2 secs.  Memory used: 184.0 Mb.
# + 68433: mip =     not found yet >=   2.922339654e+02        (90; 0)
# + 68434: mip =     not found yet >=   2.922339654e+02        (91; 0)
# + 68435: mip =     not found yet >=   2.922339654e+02        (92; 0)
# + 68436: mip =     not found yet >=   2.922339654e+02        (93; 0)
# + 68437: mip =     not found yet >=   2.922339654e+02        (94; 0)
# Time used: 1277.3 secs.  Memory used: 184.0 Mb.
# + 68438: mip =     not found yet >=   2.922339654e+02        (95; 0)
# + 68439: mip =     not found yet >=   2.922339654e+02        (96; 0)
# + 68440: mip =     not found yet >=   2.922339654e+02        (97; 0)
# + 68441: mip =     not found yet >=   2.922339654e+02        (98; 0)
# Time used: 1338.6 secs.  Memory used: 184.0 Mb.
# + 68442: mip =     not found yet >=   2.922339654e+02        (99; 0)
# + 68443: mip =     not found yet >=   2.922339654e+02        (100; 0)
# + 68445: mip =     not found yet >=   2.922339654e+02        (101; 0)
# + 68446: mip =     not found yet >=   2.922339654e+02        (102; 0)
# + 68448: mip =     not found yet >=   2.922339654e+02        (103; 0)
# Time used: 1407.4 secs.  Memory used: 184.0 Mb.
# + 68449: mip =     not found yet >=   2.922339654e+02        (104; 0)
# + 68450: mip =     not found yet >=   2.922339654e+02        (105; 0)
# + 68451: mip =     not found yet >=   2.922339654e+02        (106; 0)
# + 68452: mip =     not found yet >=   2.922339654e+02        (107; 0)
# + 68454: mip =     not found yet >=   2.922339654e+02        (108; 0)
# Time used: 1480.8 secs.  Memory used: 184.0 Mb.
# + 68455: mip =     not found yet >=   2.922339654e+02        (109; 0)
# + 68468: mip =     not found yet >=   2.922339654e+02        (110; 0)
# + 68470: mip =     not found yet >=   2.922339654e+02        (111; 0)
# + 68471: mip =     not found yet >=   2.922339654e+02        (112; 0)
# + 68472: mip =     not found yet >=   2.922339654e+02        (113; 0)
# Time used: 1546.8 secs.  Memory used: 184.0 Mb.
# + 68473: mip =     not found yet >=   2.922339654e+02        (114; 0)
# + 68474: mip =     not found yet >=   2.922339654e+02        (115; 0)
# + 68479: mip =     not found yet >=   2.922339654e+02        (116; 0)
# + 68482: mip =     not found yet >=   2.922339654e+02        (117; 0)
# + 68483: mip =     not found yet >=   2.922339654e+02        (118; 0)
# Time used: 1615.2 secs.  Memory used: 184.0 Mb.
# + 68488: mip =     not found yet >=   2.922339654e+02        (119; 0)
# + 68490: mip =     not found yet >=   2.922339654e+02        (120; 0)
# + 68491: mip =     not found yet >=   2.922339654e+02        (121; 0)
# + 68492: mip =     not found yet >=   2.922339654e+02        (122; 0)
# + 68493: mip =     not found yet >=   2.922339654e+02        (123; 0)
# Time used: 1684.6 secs.  Memory used: 184.0 Mb.
# + 68494: mip =     not found yet >=   2.922339654e+02        (124; 0)
# + 68495: mip =     not found yet >=   2.922339654e+02        (125; 0)
# + 68496: mip =     not found yet >=   2.922339654e+02        (126; 0)
# + 68497: mip =     not found yet >=   2.922339654e+02        (127; 0)
# + 68498: mip =     not found yet >=   2.922339654e+02        (128; 0)
# Time used: 1746.9 secs.  Memory used: 184.0 Mb.
# + 68501: mip =     not found yet >=   2.922339654e+02        (129; 0)
# + 68503: mip =     not found yet >=   2.922339654e+02        (130; 0)
# + 68507: mip =     not found yet >=   2.922339654e+02        (131; 0)
# + 68509: mip =     not found yet >=   2.922339654e+02        (132; 0)
# + 68510: mip =     not found yet >=   2.922339654e+02        (133; 0)
# Time used: 1815.6 secs.  Memory used: 184.0 Mb.
# + 68511: mip =     not found yet >=   2.922339654e+02        (134; 0)
# + 68512: mip =     not found yet >=   2.922339654e+02        (135; 0)
# + 68513: mip =     not found yet >=   2.922339654e+02        (136; 0)
# + 68514: mip =     not found yet >=   2.922339654e+02        (137; 0)
# + 68515: mip =     not found yet >=   2.922339654e+02        (138; 0)
# + 68516: mip =     not found yet >=   2.922339654e+02        (139; 0)
# Time used: 1889.9 secs.  Memory used: 184.0 Mb.
# + 68517: mip =     not found yet >=   2.922339654e+02        (140; 0)
# + 68518: mip =     not found yet >=   2.922339654e+02        (141; 0)
# + 68519: mip =     not found yet >=   2.922339654e+02        (142; 0)
# + 68520: mip =     not found yet >=   2.922339654e+02        (143; 0)
# + 68521: mip =     not found yet >=   2.922339654e+02        (144; 0)
# Time used: 1953.3 secs.  Memory used: 184.0 Mb.
# + 68522: mip =     not found yet >=   2.922339654e+02        (145; 0)
# + 68523: mip =     not found yet >=   2.922339654e+02        (146; 0)
# + 68524: mip =     not found yet >=   2.922339654e+02        (147; 0)
# + 68525: mip =     not found yet >=   2.922339654e+02        (148; 0)
# + 68526: mip =     not found yet >=   2.922339654e+02        (149; 0)
# Time used: 2015.9 secs.  Memory used: 184.0 Mb.
# + 68527: mip =     not found yet >=   2.922339654e+02        (150; 0)
# + 68528: mip =     not found yet >=   2.922339654e+02        (151; 0)
# + 68529: mip =     not found yet >=   2.922339654e+02        (152; 0)
# + 68533: mip =     not found yet >=   2.922339654e+02        (153; 0)
# + 68535: mip =     not found yet >=   2.922339654e+02        (154; 0)
# Time used: 2083.6 secs.  Memory used: 184.0 Mb.
# + 68539: mip =     not found yet >=   2.922339654e+02        (155; 0)
# + 68544: mip =     not found yet >=   2.922339654e+02        (156; 0)
# + 68545: mip =     not found yet >=   2.922339654e+02        (157; 0)
# + 68546: mip =     not found yet >=   2.922339654e+02        (158; 0)
# + 68547: mip =     not found yet >=   2.922339654e+02        (159; 0)
# Time used: 2154.4 secs.  Memory used: 184.0 Mb.
# + 68548: mip =     not found yet >=   2.922339654e+02        (160; 0)
# + 68549: mip =     not found yet >=   2.922339654e+02        (161; 0)
# + 68551: mip =     not found yet >=   2.922339654e+02        (162; 0)
# + 68552: mip =     not found yet >=   2.922339654e+02        (163; 0)
# + 68553: mip =     not found yet >=   2.922339654e+02        (164; 0)
# Time used: 2217.6 secs.  Memory used: 184.1 Mb.
# + 68554: mip =     not found yet >=   2.922339654e+02        (165; 0)
# + 68555: mip =     not found yet >=   2.922339654e+02        (166; 0)
# + 68556: mip =     not found yet >=   2.922339654e+02        (167; 0)
# + 68557: mip =     not found yet >=   2.922339654e+02        (168; 0)
# + 68558: mip =     not found yet >=   2.922339654e+02        (169; 0)
# Time used: 2279.1 secs.  Memory used: 184.1 Mb.
# + 68559: mip =     not found yet >=   2.922339654e+02        (170; 0)
# + 68560: mip =     not found yet >=   2.922339654e+02        (171; 0)
# + 68561: mip =     not found yet >=   2.922339654e+02        (172; 0)
# + 68562: mip =     not found yet >=   2.922339654e+02        (173; 0)
# + 68563: mip =     not found yet >=   2.922339654e+02        (174; 0)
# Time used: 2343.1 secs.  Memory used: 184.1 Mb.
# + 68565: mip =     not found yet >=   2.922339654e+02        (175; 0)
# + 68568: mip =     not found yet >=   2.922339654e+02        (176; 0)
# + 68569: mip =     not found yet >=   2.922339654e+02        (177; 0)
# + 68570: mip =     not found yet >=   2.922339654e+02        (178; 0)
# + 68571: mip =     not found yet >=   2.922339654e+02        (179; 0)
# Time used: 2404.8 secs.  Memory used: 184.1 Mb.
# + 68572: mip =     not found yet >=   2.922339654e+02        (180; 0)
# + 68573: mip =     not found yet >=   2.922339654e+02        (181; 0)
# + 68574: mip =     not found yet >=   2.922339654e+02        (182; 0)
# + 68575: mip =     not found yet >=   2.922339654e+02        (183; 0)
# Time used: 2465.1 secs.  Memory used: 184.1 Mb.
# + 68576: mip =     not found yet >=   2.922339654e+02        (184; 0)
# + 68579: mip =     not found yet >=   2.922339654e+02        (185; 0)
# + 68581: mip =     not found yet >=   2.922339654e+02        (186; 0)
# + 68582: mip =     not found yet >=   2.922339654e+02        (187; 0)
# Time used: 2526.6 secs.  Memory used: 184.1 Mb.
# + 68584: mip =     not found yet >=   2.922339654e+02        (188; 0)
# + 68585: mip =     not found yet >=   2.922339654e+02        (189; 0)
# + 68586: mip =     not found yet >=   2.922339654e+02        (190; 0)
# + 68587: mip =     not found yet >=   2.922339654e+02        (191; 0)
# + 68588: mip =     not found yet >=   2.922339654e+02        (192; 0)
# Time used: 2602.5 secs.  Memory used: 184.1 Mb.
# + 68589: mip =     not found yet >=   2.922339654e+02        (193; 0)
# + 68590: mip =     not found yet >=   2.922339654e+02        (194; 0)
# + 68591: mip =     not found yet >=   2.922339654e+02        (195; 0)
# + 68593: mip =     not found yet >=   2.922339654e+02        (196; 0)
# Time used: 2672.2 secs.  Memory used: 184.1 Mb.
# + 68594: mip =     not found yet >=   2.922339654e+02        (197; 0)
# + 68595: mip =     not found yet >=   2.922339654e+02        (198; 0)
# + 68596: mip =     not found yet >=   2.922339654e+02        (199; 0)
# + 68597: mip =     not found yet >=   2.922339654e+02        (200; 0)
# Time used: 2738.7 secs.  Memory used: 184.1 Mb.
# + 68599: mip =     not found yet >=   2.922339654e+02        (201; 0)
# + 68600: mip =     not found yet >=   2.922339654e+02        (202; 0)
# + 68601: mip =     not found yet >=   2.922339654e+02        (203; 0)
# + 68602: mip =     not found yet >=   2.922339654e+02        (204; 0)
# Time used: 2804.6 secs.  Memory used: 184.1 Mb.
# + 68603: mip =     not found yet >=   2.922339654e+02        (205; 0)
# + 68604: mip =     not found yet >=   2.922339654e+02        (206; 0)
# + 68605: mip =     not found yet >=   2.922339654e+02        (207; 0)
# + 68606: mip =     not found yet >=   2.922339654e+02        (208; 0)
# Time used: 2870.5 secs.  Memory used: 184.1 Mb.
# + 68607: mip =     not found yet >=   2.922339654e+02        (209; 0)
# + 68609: mip =     not found yet >=   2.922339654e+02        (210; 0)
# + 68611: mip =     not found yet >=   2.922339654e+02        (211; 0)
# + 68613: mip =     not found yet >=   2.922339654e+02        (212; 0)
# Time used: 2936.5 secs.  Memory used: 184.1 Mb.
# + 68614: mip =     not found yet >=   2.922339654e+02        (213; 0)
# + 68615: mip =     not found yet >=   2.922339654e+02        (214; 0)
# + 68616: mip =     not found yet >=   2.922339654e+02        (215; 0)
# + 68617: mip =     not found yet >=   2.922339654e+02        (216; 0)
# Time used: 3002.1 secs.  Memory used: 184.1 Mb.
# + 68618: mip =     not found yet >=   2.922339654e+02        (217; 0)
# + 68619: mip =     not found yet >=   2.922339654e+02        (218; 0)
# + 68620: mip =     not found yet >=   2.922339654e+02        (219; 0)
# + 68621: mip =     not found yet >=   2.922339654e+02        (220; 0)
# Time used: 3068.3 secs.  Memory used: 184.1 Mb.
# + 68621: mip =     not found yet >=   2.922339654e+02        (221; 0)
# + 68621: mip =     not found yet >=   2.922339654e+02        (222; 0)
# + 68621: mip =     not found yet >=   2.922339654e+02        (223; 0)
# + 68621: mip =     not found yet >=   2.922339654e+02        (224; 0)
# Time used: 3153.0 secs.  Memory used: 184.1 Mb.
# + 68622: mip =     not found yet >=   2.922339654e+02        (225; 0)
# + 68623: mip =     not found yet >=   2.922339654e+02        (226; 0)
# + 68624: mip =     not found yet >=   2.922339654e+02        (227; 0)
# Time used: 3241.8 secs.  Memory used: 184.1 Mb.
# + 68625: mip =     not found yet >=   2.922339654e+02        (228; 0)
# + 68626: mip =     not found yet >=   2.922339654e+02        (229; 0)
# + 68627: mip =     not found yet >=   2.922339654e+02        (230; 0)
# Time used: 3330.4 secs.  Memory used: 184.1 Mb.
# + 68628: mip =     not found yet >=   2.922339654e+02        (231; 0)
# + 68629: mip =     not found yet >=   2.922339654e+02        (232; 0)
# + 68630: mip =     not found yet >=   2.922339654e+02        (233; 0)
# Time used: 3418.4 secs.  Memory used: 184.1 Mb.
# + 68631: mip =     not found yet >=   2.922339654e+02        (234; 0)
# + 68632: mip =     not found yet >=   2.922339654e+02        (235; 0)
# + 68633: mip =     not found yet >=   2.922339654e+02        (236; 0)
# Time used: 3506.4 secs.  Memory used: 184.1 Mb.
# + 68635: mip =     not found yet >=   2.922339654e+02        (237; 0)
# + 68636: mip =     not found yet >=   2.922339654e+02        (238; 0)
# + 68637: mip =     not found yet >=   2.922339654e+02        (239; 0)
# Time used: 3594.0 secs.  Memory used: 184.1 Mb.
# + 68638: mip =     not found yet >=   2.922339654e+02        (240; 0)
# + 68639: mip =     not found yet >=   2.922339654e+02        (241; 0)
# + 68640: mip =     not found yet >=   2.922339654e+02        (242; 0)
# Time used: 3682.0 secs.  Memory used: 184.1 Mb.
# + 68641: mip =     not found yet >=   2.922339654e+02        (243; 0)
# + 68643: mip =     not found yet >=   2.922339654e+02        (244; 0)
# + 68645: mip =     not found yet >=   2.922339654e+02        (245; 0)
# Time used: 3769.9 secs.  Memory used: 184.1 Mb.
# + 68647: mip =     not found yet >=   2.922339654e+02        (246; 0)
# + 68649: mip =     not found yet >=   2.922339654e+02        (247; 0)
# + 68650: mip =     not found yet >=   2.922339654e+02        (248; 0)
# Time used: 3857.5 secs.  Memory used: 184.1 Mb.
# + 68651: mip =     not found yet >=   2.922339654e+02        (249; 0)
# + 68652: mip =     not found yet >=   2.922339654e+02        (250; 0)
# + 68655: mip =     not found yet >=   2.922339654e+02        (251; 0)
# Time used: 3945.1 secs.  Memory used: 184.1 Mb.
# + 68658: mip =     not found yet >=   2.922339654e+02        (252; 0)
# + 68661: mip =     not found yet >=   2.922339654e+02        (253; 0)
# + 68663: mip =     not found yet >=   2.922339654e+02        (254; 0)
# Time used: 4032.3 secs.  Memory used: 184.1 Mb.
# + 68664: mip =     not found yet >=   2.922339654e+02        (255; 0)
# + 68665: mip =     not found yet >=   2.922339654e+02        (256; 0)
# + 68666: mip =     not found yet >=   2.922339654e+02        (257; 0)
# Time used: 4119.5 secs.  Memory used: 184.1 Mb.
# + 68667: mip =     not found yet >=   2.922339654e+02        (258; 0)
# + 68669: mip =     not found yet >=   2.922339654e+02        (259; 0)
# + 68670: mip =     not found yet >=   2.922339654e+02        (260; 0)
# Time used: 4206.5 secs.  Memory used: 184.1 Mb.
# + 68671: mip =     not found yet >=   2.922339654e+02        (261; 0)
# + 68672: mip =     not found yet >=   2.922339654e+02        (262; 0)
# + 68673: mip =     not found yet >=   2.922339654e+02        (263; 0)
# Time used: 4293.2 secs.  Memory used: 184.1 Mb.
# + 68675: mip =     not found yet >=   2.922339654e+02        (264; 0)
# + 68677: mip =     not found yet >=   2.922339654e+02        (265; 0)
# + 68679: mip =     not found yet >=   2.922339654e+02        (266; 0)
# Time used: 4379.5 secs.  Memory used: 184.1 Mb.
# + 68681: mip =     not found yet >=   2.922339654e+02        (267; 0)
# + 68682: mip =     not found yet >=   2.922339654e+02        (268; 0)
# + 68685: mip =     not found yet >=   2.922339654e+02        (269; 0)
# Time used: 4465.8 secs.  Memory used: 184.1 Mb.
# + 68687: mip =     not found yet >=   2.922339654e+02        (270; 0)
# + 68688: mip =     not found yet >=   2.922339654e+02        (271; 0)
# + 68689: mip =     not found yet >=   2.922339654e+02        (272; 0)
# Time used: 4552.0 secs.  Memory used: 184.1 Mb.
# + 68690: mip =     not found yet >=   2.922339654e+02        (273; 0)
# + 68691: mip =     not found yet >=   2.922339654e+02        (274; 0)
# + 68692: mip =     not found yet >=   2.922339654e+02        (275; 0)
# Time used: 4638.3 secs.  Memory used: 184.1 Mb.
# + 68693: mip =     not found yet >=   2.922339654e+02        (276; 0)
# + 68694: mip =     not found yet >=   2.922339654e+02        (277; 0)
# + 68695: mip =     not found yet >=   2.922339654e+02        (278; 0)
# Time used: 4724.6 secs.  Memory used: 184.1 Mb.
# + 68696: mip =     not found yet >=   2.922339654e+02        (279; 0)
# + 68697: mip =     not found yet >=   2.922339654e+02        (280; 0)
# + 68698: mip =     not found yet >=   2.922339654e+02        (281; 0)
# Time used: 4810.4 secs.  Memory used: 184.1 Mb.
# + 68699: mip =     not found yet >=   2.922339654e+02        (282; 0)
# + 68700: mip =     not found yet >=   2.922339654e+02        (283; 0)
# + 68701: mip =     not found yet >=   2.922339654e+02        (284; 0)
# Time used: 4896.1 secs.  Memory used: 184.1 Mb.
# + 68702: mip =     not found yet >=   2.922339654e+02        (285; 0)
# + 68703: mip =     not found yet >=   2.922339654e+02        (286; 0)
# + 68704: mip =     not found yet >=   2.922339654e+02        (287; 0)
# Time used: 4981.9 secs.  Memory used: 184.1 Mb.
# + 68705: mip =     not found yet >=   2.922339654e+02        (288; 0)
# + 68706: mip =     not found yet >=   2.922339654e+02        (289; 0)
# + 68707: mip =     not found yet >=   2.922339654e+02        (290; 0)
# Time used: 5066.1 secs.  Memory used: 184.1 Mb.
# + 68708: mip =     not found yet >=   2.922339654e+02        (291; 0)
# + 68709: mip =     not found yet >=   2.922339654e+02        (292; 0)
# + 68712: mip =     not found yet >=   2.922339654e+02        (293; 0)
# Time used: 5138.8 secs.  Memory used: 184.1 Mb.
# + 68713: mip =     not found yet >=   2.922339654e+02        (294; 0)
# + 68715: mip =     not found yet >=   2.922339654e+02        (295; 0)
# + 68716: mip =     not found yet >=   2.922339654e+02        (296; 0)
# Time used: 5211.9 secs.  Memory used: 184.1 Mb.
# + 68719: mip =     not found yet >=   2.922339654e+02        (297; 0)
# + 68721: mip =     not found yet >=   2.922339654e+02        (298; 0)
# + 68722: mip =     not found yet >=   2.922339654e+02        (299; 0)
# Time used: 5286.8 secs.  Memory used: 184.1 Mb.
# + 68723: mip =     not found yet >=   2.922339654e+02        (300; 0)
# + 68724: mip =     not found yet >=   2.922339654e+02        (301; 0)
# + 68725: mip =     not found yet >=   2.922339654e+02        (302; 0)
# + 68726: mip =     not found yet >=   2.922339654e+02        (303; 0)
# Time used: 5347.4 secs.  Memory used: 184.1 Mb.
# + 68727: mip =     not found yet >=   2.922339654e+02        (304; 0)
# + 68728: mip =     not found yet >=   2.922339654e+02        (305; 0)
# + 68729: mip =     not found yet >=   2.922339654e+02        (306; 0)
# + 68730: mip =     not found yet >=   2.922339654e+02        (307; 0)
# + 68732: mip =     not found yet >=   2.922339654e+02        (308; 0)
# Time used: 5409.6 secs.  Memory used: 184.1 Mb.
# + 68734: mip =     not found yet >=   2.922339654e+02        (309; 0)
# + 68736: mip =     not found yet >=   2.922339654e+02        (310; 0)
# + 68738: mip =     not found yet >=   2.922339654e+02        (311; 0)
# + 68744: mip =     not found yet >=   2.922339654e+02        (312; 0)
# + 68746: mip =     not found yet >=   2.922339654e+02        (313; 0)
# Time used: 5474.9 secs.  Memory used: 184.1 Mb.
# + 68747: mip =     not found yet >=   2.922339654e+02        (314; 0)
# + 68748: mip =     not found yet >=   2.922339654e+02        (315; 0)
# + 68750: mip =     not found yet >=   2.922339654e+02        (316; 0)
# + 68751: mip =     not found yet >=   2.922339654e+02        (317; 0)
# + 68752: mip =     not found yet >=   2.922339654e+02        (318; 0)
# Time used: 5550.1 secs.  Memory used: 184.1 Mb.
# + 68753: mip =     not found yet >=   2.922339654e+02        (319; 0)
# + 68754: mip =     not found yet >=   2.922339654e+02        (320; 0)
# + 68756: mip =     not found yet >=   2.922339654e+02        (321; 0)
# + 68757: mip =     not found yet >=   2.922339654e+02        (322; 0)
# Time used: 5611.9 secs.  Memory used: 184.1 Mb.
# + 68758: mip =     not found yet >=   2.922339654e+02        (323; 0)
# + 68759: mip =     not found yet >=   2.922339654e+02        (324; 0)
# + 68760: mip =     not found yet >=   2.922339654e+02        (325; 0)
# + 68763: mip =     not found yet >=   2.922339654e+02        (326; 0)
# Time used: 5674.0 secs.  Memory used: 184.1 Mb.
# + 68764: mip =     not found yet >=   2.922339654e+02        (327; 0)
# + 68765: mip =     not found yet >=   2.922339654e+02        (328; 0)
# + 68766: mip =     not found yet >=   2.922339654e+02        (329; 0)
# + 68767: mip =     not found yet >=   2.922339654e+02        (330; 0)
# + 68768: mip =     not found yet >=   2.922339654e+02        (331; 0)
# Time used: 5743.5 secs.  Memory used: 184.1 Mb.
# + 68769: mip =     not found yet >=   2.922339654e+02        (332; 0)
# + 68770: mip =     not found yet >=   2.922339654e+02        (333; 0)
# + 68771: mip =     not found yet >=   2.922339654e+02        (334; 0)
# + 68772: mip =     not found yet >=   2.922339654e+02        (335; 0)
# + 68773: mip =     not found yet >=   2.922339654e+02        (336; 0)
# + 68774: mip =     not found yet >=   2.922339654e+02        (337; 0)
# Time used: 5814.4 secs.  Memory used: 184.1 Mb.
# + 68777: mip =     not found yet >=   2.922339654e+02        (338; 0)
# + 68780: mip =     not found yet >=   2.922339654e+02        (339; 0)
# + 68783: mip =     not found yet >=   2.922339654e+02        (340; 0)
# + 68785: mip =     not found yet >=   2.922339654e+02        (341; 0)
# + 68790: mip =     not found yet >=   2.922339654e+02        (342; 0)
# + 68791: mip =     not found yet >=   2.922339654e+02        (343; 0)
# Time used: 5883.0 secs.  Memory used: 184.1 Mb.
# + 68792: mip =     not found yet >=   2.922339654e+02        (344; 0)
# + 68793: mip =     not found yet >=   2.922339654e+02        (345; 0)
# + 68794: mip =     not found yet >=   2.922339654e+02        (346; 0)
# + 68796: mip =     not found yet >=   2.922339654e+02        (347; 0)
# + 68798: mip =     not found yet >=   2.922339654e+02        (348; 0)
# Time used: 5949.8 secs.  Memory used: 184.1 Mb.
# + 68800: mip =     not found yet >=   2.922339654e+02        (349; 0)
# + 68801: mip =     not found yet >=   2.922339654e+02        (350; 0)
# + 68802: mip =     not found yet >=   2.922339654e+02        (351; 0)
# + 68803: mip =     not found yet >=   2.922339654e+02        (352; 0)
# + 68804: mip =     not found yet >=   2.922339654e+02        (353; 0)
# + 68805: mip =     not found yet >=   2.922339654e+02        (354; 0)
# Time used: 6020.6 secs.  Memory used: 184.1 Mb.
# + 68805: mip =     not found yet >=   2.922339654e+02        (355; 0)
# + 68805: mip =     not found yet >=   2.922339654e+02        (356; 0)
# + 68806: mip =     not found yet >=   2.922339654e+02        (357; 0)
# + 68806: mip =     not found yet >=   2.922339654e+02        (358; 0)
# + 68808: mip =     not found yet >=   2.922339654e+02        (359; 0)
# Time used: 6087.0 secs.  Memory used: 184.2 Mb.
# + 68810: mip =     not found yet >=   2.922339654e+02        (360; 0)
# + 68812: mip =     not found yet >=   2.922339654e+02        (361; 0)
# + 68813: mip =     not found yet >=   2.922339654e+02        (362; 0)
# + 68814: mip =     not found yet >=   2.922339654e+02        (363; 0)
# Time used: 6147.3 secs.  Memory used: 184.2 Mb.
# + 68815: mip =     not found yet >=   2.922339654e+02        (364; 0)
# + 68816: mip =     not found yet >=   2.922339654e+02        (365; 0)
# + 68817: mip =     not found yet >=   2.922339654e+02        (366; 0)
# + 68818: mip =     not found yet >=   2.922339654e+02        (367; 0)
# + 68819: mip =     not found yet >=   2.922339654e+02        (368; 0)
# Time used: 6211.1 secs.  Memory used: 184.2 Mb.
# + 68820: mip =     not found yet >=   2.922339654e+02        (369; 0)
# + 68821: mip =     not found yet >=   2.922339654e+02        (370; 0)
# + 68824: mip =     not found yet >=   2.922339654e+02        (371; 0)
# + 68826: mip =     not found yet >=   2.922339654e+02        (372; 0)
# + 68829: mip =     not found yet >=   2.922339654e+02        (373; 0)
# Time used: 6274.8 secs.  Memory used: 184.2 Mb.
# + 68831: mip =     not found yet >=   2.922339654e+02        (374; 0)
# + 68832: mip =     not found yet >=   2.922339654e+02        (375; 0)
# + 68833: mip =     not found yet >=   2.922339654e+02        (376; 0)
# + 68834: mip =     not found yet >=   2.922339654e+02        (377; 0)
# + 68835: mip =     not found yet >=   2.922339654e+02        (378; 0)
# Time used: 6338.9 secs.  Memory used: 184.2 Mb.
# + 68835: mip =     not found yet >=   2.922339654e+02        (379; 0)
# + 68835: mip =     not found yet >=   2.922339654e+02        (380; 0)
# + 68836: mip =     not found yet >=   2.922339654e+02        (381; 0)
# + 68836: mip =     not found yet >=   2.922339654e+02        (382; 0)
# + 68837: mip =     not found yet >=   2.922339654e+02        (383; 0)
# + 68838: mip =     not found yet >=   2.922339654e+02        (384; 0)
# Time used: 6409.8 secs.  Memory used: 184.2 Mb.
# + 68839: mip =     not found yet >=   2.922339654e+02        (385; 0)
# + 68840: mip =     not found yet >=   2.922339654e+02        (386; 0)
# + 68842: mip =     not found yet >=   2.922339654e+02        (387; 0)
# + 68843: mip =     not found yet >=   2.922339654e+02        (388; 0)
# + 68844: mip =     not found yet >=   2.922339654e+02        (389; 0)
# + 68845: mip =     not found yet >=   2.922339654e+02        (390; 0)
# Time used: 6477.1 secs.  Memory used: 184.2 Mb.
# + 68846: mip =     not found yet >=   2.922339654e+02        (391; 0)
# + 68847: mip =     not found yet >=   2.922339654e+02        (392; 0)
# + 68848: mip =     not found yet >=   2.922339654e+02        (393; 0)
# + 68850: mip =     not found yet >=   2.922339654e+02        (394; 0)
# + 68853: mip =     not found yet >=   2.922339654e+02        (395; 0)
# + 68856: mip =     not found yet >=   2.922339654e+02        (396; 0)
# Time used: 6547.8 secs.  Memory used: 184.2 Mb.
# + 68859: mip =     not found yet >=   2.922339654e+02        (397; 0)
# + 68863: mip =     not found yet >=   2.922339654e+02        (398; 0)
# + 68866: mip =     not found yet >=   2.922339654e+02        (399; 0)
# + 68870: mip =     not found yet >=   2.922339654e+02        (400; 0)
# + 68871: mip =     not found yet >=   2.922339654e+02        (401; 0)
# Time used: 6608.8 secs.  Memory used: 184.2 Mb.
# + 68872: mip =     not found yet >=   2.922339654e+02        (402; 0)
# + 68873: mip =     not found yet >=   2.922339654e+02        (403; 0)
# + 68874: mip =     not found yet >=   2.922339654e+02        (404; 0)
# + 68875: mip =     not found yet >=   2.922339654e+02        (405; 0)
# + 68876: mip =     not found yet >=   2.922339654e+02        (406; 0)
# + 68877: mip =     not found yet >=   2.922339654e+02        (407; 0)
# Time used: 6675.6 secs.  Memory used: 184.2 Mb.
# + 68879: mip =     not found yet >=   2.922339654e+02        (408; 0)
# + 68880: mip =     not found yet >=   2.922339654e+02        (409; 0)
# + 68882: mip =     not found yet >=   2.922339654e+02        (410; 0)
# + 68883: mip =     not found yet >=   2.922339654e+02        (411; 0)
# + 68885: mip =     not found yet >=   2.922339654e+02        (412; 0)
# Time used: 6735.6 secs.  Memory used: 184.2 Mb.
# + 68888: mip =     not found yet >=   2.922339654e+02        (413; 0)
# + 68890: mip =     not found yet >=   2.922339654e+02        (414; 0)
# + 68891: mip =     not found yet >=   2.922339654e+02        (415; 0)
# + 68892: mip =     not found yet >=   2.922339654e+02        (416; 0)
# + 68893: mip =     not found yet >=   2.922339654e+02        (417; 0)
# + 68894: mip =     not found yet >=   2.922339654e+02        (418; 0)
# Time used: 6806.2 secs.  Memory used: 184.2 Mb.
# + 68896: mip =     not found yet >=   2.922339654e+02        (419; 0)
# + 68899: mip =     not found yet >=   2.922339654e+02        (420; 0)
# + 68903: mip =     not found yet >=   2.922339654e+02        (421; 0)
# + 68907: mip =     not found yet >=   2.922339654e+02        (422; 0)
# + 68909: mip =     not found yet >=   2.922339654e+02        (423; 0)
# + 68914: mip =     not found yet >=   2.922339654e+02        (424; 0)
# Time used: 6872.8 secs.  Memory used: 184.2 Mb.
# + 68915: mip =     not found yet >=   2.922339654e+02        (425; 0)
# + 68916: mip =     not found yet >=   2.922339654e+02        (426; 0)
# + 68917: mip =     not found yet >=   2.922339654e+02        (427; 0)
# + 68918: mip =     not found yet >=   2.922339654e+02        (428; 0)
# + 68919: mip =     not found yet >=   2.922339654e+02        (429; 0)
# + 68932: mip =     not found yet >=   2.922339654e+02        (430; 0)
# Time used: 6940.7 secs.  Memory used: 184.2 Mb.
# + 68933: mip =     not found yet >=   2.922339654e+02        (431; 0)
# + 68934: mip =     not found yet >=   2.922339654e+02        (432; 0)
# + 68937: mip =     not found yet >=   2.922339654e+02        (433; 0)
# + 68938: mip =     not found yet >=   2.922339654e+02        (434; 0)
# + 68941: mip =     not found yet >=   2.922339654e+02        (435; 0)
# + 68944: mip =     not found yet >=   2.922339654e+02        (436; 0)
# Time used: 7009.3 secs.  Memory used: 184.2 Mb.
# + 68947: mip =     not found yet >=   2.922339654e+02        (437; 0)
# + 68950: mip =     not found yet >=   2.922339654e+02        (438; 0)
# + 68952: mip =     not found yet >=   2.922339654e+02        (439; 0)
# + 68954: mip =     not found yet >=   2.922339654e+02        (440; 0)
# + 68956: mip =     not found yet >=   2.922339654e+02        (441; 0)
# + 68960: mip =     not found yet >=   2.922339654e+02        (442; 0)
# Time used: 7072.4 secs.  Memory used: 184.2 Mb.
# + 68961: mip =     not found yet >=   2.922339654e+02        (443; 0)
# + 68963: mip =     not found yet >=   2.922339654e+02        (444; 0)
# + 68964: mip =     not found yet >=   2.922339654e+02        (445; 0)
# + 68965: mip =     not found yet >=   2.922339654e+02        (446; 0)
# + 68966: mip =     not found yet >=   2.922339654e+02        (447; 0)
# + 68967: mip =     not found yet >=   2.922339654e+02        (448; 0)
# Time used: 7137.8 secs.  Memory used: 184.2 Mb.
# + 68968: mip =     not found yet >=   2.922339654e+02        (449; 0)
# + 68969: mip =     not found yet >=   2.922339654e+02        (450; 0)
# + 68971: mip =     not found yet >=   2.922339654e+02        (451; 0)
# + 68973: mip =     not found yet >=   2.922339654e+02        (452; 0)
# + 68974: mip =     not found yet >=   2.922339654e+02        (453; 0)
# Time used: 7198.6 secs.  Memory used: 184.2 Mb.
# + 68975: mip =     not found yet >=   2.922339654e+02        (454; 0)
# + 68976: mip =     not found yet >=   2.922339654e+02        (455; 0)
# + 68977: mip =     not found yet >=   2.922339654e+02        (456; 0)
# + 68978: mip =     not found yet >=   2.922339654e+02        (457; 0)
# + 68979: mip =     not found yet >=   2.922339654e+02        (458; 0)
# Time used: 7262.0 secs.  Memory used: 184.2 Mb.
# + 68980: mip =     not found yet >=   2.922339654e+02        (459; 0)
# + 68982: mip =     not found yet >=   2.922339654e+02        (460; 0)
# + 68984: mip =     not found yet >=   2.922339654e+02        (461; 0)
# + 68986: mip =     not found yet >=   2.922339654e+02        (462; 0)
# + 68989: mip =     not found yet >=   2.922339654e+02        (463; 0)
# Time used: 7322.9 secs.  Memory used: 184.2 Mb.
# + 68991: mip =     not found yet >=   2.922339654e+02        (464; 0)
# + 68991: mip =     not found yet >=   2.922339654e+02        (465; 0)
# + 68991: mip =     not found yet >=   2.922339654e+02        (466; 0)
# + 68991: mip =     not found yet >=   2.922339654e+02        (467; 0)
# + 68991: mip =     not found yet >=   2.922339654e+02        (468; 0)
# + 68992: mip =     not found yet >=   2.922339654e+02        (469; 0)
# Time used: 7386.2 secs.  Memory used: 184.2 Mb.
# + 68993: mip =     not found yet >=   2.922339654e+02        (470; 0)
# + 68994: mip =     not found yet >=   2.922339654e+02        (471; 0)
# + 68995: mip =     not found yet >=   2.922339654e+02        (472; 0)
# + 68995: mip =     not found yet >=   2.922339654e+02        (473; 0)
# + 68996: mip =     not found yet >=   2.922339654e+02        (474; 0)
# + 68996: mip =     not found yet >=   2.922339654e+02        (475; 0)
# Time used: 7448.4 secs.  Memory used: 184.2 Mb.
# + 68997: mip =     not found yet >=   2.922339654e+02        (476; 0)
# + 68999: mip =     not found yet >=   2.922339654e+02        (477; 0)
# + 69001: mip =     not found yet >=   2.922339654e+02        (478; 0)
# + 69003: mip =     not found yet >=   2.922339654e+02        (479; 0)
# + 69004: mip =     not found yet >=   2.922339654e+02        (480; 0)
# + 69006: mip =     not found yet >=   2.922339654e+02        (481; 0)
# + 69007: mip =     not found yet >=   2.922339654e+02        (482; 0)
# Time used: 7518.2 secs.  Memory used: 184.2 Mb.
# + 69009: mip =     not found yet >=   2.922339654e+02        (483; 0)
# + 69010: mip =     not found yet >=   2.922339654e+02        (484; 0)
# + 69011: mip =     not found yet >=   2.922339654e+02        (485; 0)
# + 69012: mip =     not found yet >=   2.922339654e+02        (486; 0)
# + 69013: mip =     not found yet >=   2.922339654e+02        (487; 0)
# + 69014: mip =     not found yet >=   2.922339654e+02        (488; 0)
# Time used: 7584.6 secs.  Memory used: 184.2 Mb.
# + 69015: mip =     not found yet >=   2.922339654e+02        (489; 0)
# + 69016: mip =     not found yet >=   2.922339654e+02        (490; 0)
# + 69017: mip =     not found yet >=   2.922339654e+02        (491; 0)
# + 69018: mip =     not found yet >=   2.922339654e+02        (492; 0)
# + 69019: mip =     not found yet >=   2.922339654e+02        (493; 0)
# + 69022: mip =     not found yet >=   2.922339654e+02        (494; 0)
# Time used: 7654.6 secs.  Memory used: 184.2 Mb.
# + 69025: mip =     not found yet >=   2.922339654e+02        (495; 0)
# + 69026: mip =     not found yet >=   2.922339654e+02        (496; 0)
# + 69028: mip =     not found yet >=   2.922339654e+02        (497; 0)
# + 69043: mip =     not found yet >=   2.922339654e+02        (498; 0)
# + 69044: mip =     not found yet >=   2.922339654e+02        (499; 0)
# Time used: 7716.5 secs.  Memory used: 184.2 Mb.
# + 69045: mip =     not found yet >=   2.922339654e+02        (500; 0)
# + 69046: mip =     not found yet >=   2.922339654e+02        (501; 0)
# + 69047: mip =     not found yet >=   2.922339654e+02        (502; 0)
# + 69048: mip =     not found yet >=   2.922339654e+02        (503; 0)
# + 69049: mip =     not found yet >=   2.922339654e+02        (504; 0)
# Time used: 7777.9 secs.  Memory used: 184.2 Mb.
# + 69050: mip =     not found yet >=   2.922339654e+02        (505; 0)
# + 69051: mip =     not found yet >=   2.922339654e+02        (506; 0)
# + 69053: mip =     not found yet >=   2.922339654e+02        (507; 0)
# + 69055: mip =     not found yet >=   2.922339654e+02        (508; 0)
# + 69057: mip =     not found yet >=   2.922339654e+02        (509; 0)
# + 69059: mip =     not found yet >=   2.922339654e+02        (510; 0)
# Time used: 7845.5 secs.  Memory used: 184.2 Mb.
# + 69060: mip =     not found yet >=   2.922339654e+02        (511; 0)
# + 69062: mip =     not found yet >=   2.922339654e+02        (512; 0)
# + 69065: mip =     not found yet >=   2.922339654e+02        (513; 0)
# + 69067: mip =     not found yet >=   2.922339654e+02        (514; 0)
# + 69070: mip =     not found yet >=   2.922339654e+02        (515; 0)
# + 69073: mip =     not found yet >=   2.922339654e+02        (516; 0)
# Time used: 7909.7 secs.  Memory used: 184.2 Mb.
# + 69075: mip =     not found yet >=   2.922339654e+02        (517; 0)
# + 69082: mip =     not found yet >=   2.922339654e+02        (518; 0)
# + 69084: mip =     not found yet >=   2.922339654e+02        (519; 0)
# + 69086: mip =     not found yet >=   2.922339654e+02        (520; 0)
# + 69088: mip =     not found yet >=   2.922339654e+02        (521; 0)
# + 69090: mip =     not found yet >=   2.922339654e+02        (522; 0)
# Time used: 7971.7 secs.  Memory used: 184.2 Mb.
# + 69093: mip =     not found yet >=   2.922339654e+02        (523; 0)
# + 69094: mip =     not found yet >=   2.922339654e+02        (524; 0)
# + 69095: mip =     not found yet >=   2.922339654e+02        (525; 0)
# + 69096: mip =     not found yet >=   2.922339654e+02        (526; 0)
# + 69097: mip =     not found yet >=   2.922339654e+02        (527; 0)
# + 69098: mip =     not found yet >=   2.922339654e+02        (528; 0)
# Time used: 8040.8 secs.  Memory used: 184.2 Mb.
# + 69099: mip =     not found yet >=   2.922339654e+02        (529; 0)
# + 69100: mip =     not found yet >=   2.922339654e+02        (530; 0)
# + 69101: mip =     not found yet >=   2.922339654e+02        (531; 0)
# + 69102: mip =     not found yet >=   2.922339654e+02        (532; 0)
# + 69103: mip =     not found yet >=   2.922339654e+02        (533; 0)
# Time used: 8101.0 secs.  Memory used: 184.2 Mb.
# + 69104: mip =     not found yet >=   2.922339654e+02        (534; 0)
# + 69105: mip =     not found yet >=   2.922339654e+02        (535; 0)
# + 69106: mip =     not found yet >=   2.922339654e+02        (536; 0)
# + 69110: mip =     not found yet >=   2.922339654e+02        (537; 0)
# + 69113: mip =     not found yet >=   2.922339654e+02        (538; 0)
# + 69115: mip =     not found yet >=   2.922339654e+02        (539; 0)
# Time used: 8168.6 secs.  Memory used: 184.2 Mb.
# + 69118: mip =     not found yet >=   2.922339654e+02        (540; 0)
# + 69122: mip =     not found yet >=   2.922339654e+02        (541; 0)
# + 69125: mip =     not found yet >=   2.922339654e+02        (542; 0)
# + 69128: mip =     not found yet >=   2.922339654e+02        (543; 0)
# + 69130: mip =     not found yet >=   2.922339654e+02        (544; 0)
# + 69131: mip =     not found yet >=   2.922339654e+02        (545; 0)
# Time used: 8236.1 secs.  Memory used: 184.2 Mb.
# + 69132: mip =     not found yet >=   2.922339654e+02        (546; 0)
# + 69133: mip =     not found yet >=   2.922339654e+02        (547; 0)
# + 69134: mip =     not found yet >=   2.922339654e+02        (548; 0)
# + 69136: mip =     not found yet >=   2.922339654e+02        (549; 0)
# + 69137: mip =     not found yet >=   2.922339654e+02        (550; 0)
# + 69139: mip =     not found yet >=   2.922339654e+02        (551; 0)
# Time used: 8302.6 secs.  Memory used: 184.2 Mb.
# + 69141: mip =     not found yet >=   2.922339654e+02        (552; 0)
# + 69142: mip =     not found yet >=   2.922339654e+02        (553; 0)
# + 69143: mip =     not found yet >=   2.922339654e+02        (554; 0)
# + 69145: mip =     not found yet >=   2.922339654e+02        (555; 0)
# ...
# + 69872: mip =     not found yet >=   2.922339654e+02        (917; 0)
# + 69873: mip =     not found yet >=   2.922339654e+02        (918; 0)
# + 69875: mip =     not found yet >=   2.922339654e+02        (919; 0)
# + 69876: mip =     not found yet >=   2.922339654e+02        (920; 0)
# + 69877: mip =     not found yet >=   2.922339654e+02        (921; 0)
# + 69877: mip =     not found yet >=   2.922339654e+02        (922; 0)
# Time used: 11857.9 secs.  Memory used: 184.4 Mb.
# + 69877: mip =     not found yet >=   2.922339654e+02        (923; 0)
# + 69877: mip =     not found yet >=   2.922339654e+02        (924; 0)
# + 69877: mip =     not found yet >=   2.922339654e+02        (925; 0)
# + 69878: mip =     not found yet >=   2.922339654e+02        (926; 0)
# + 69880: mip =     not found yet >=   2.922339654e+02        (927; 0)
# + 69883: mip =     not found yet >=   2.922339654e+02        (928; 0)
# + 69884: mip =     not found yet >=   2.922339654e+02        (929; 0)
# Time used: 11919.4 secs.  Memory used: 184.4 Mb.
# + 69885: mip =     not found yet >=   2.922339654e+02        (930; 0)
# + 69886: mip =     not found yet >=   2.922339654e+02        (931; 0)
# + 69887: mip =     not found yet >=   2.922339654e+02        (932; 0)
# + 69887: mip =     not found yet >=   2.922339654e+02        (933; 0)
# + 69887: mip =     not found yet >=   2.922339654e+02        (934; 0)
# + 69887: mip =     not found yet >=   2.922339654e+02        (935; 0)
# + 69888: mip =     not found yet >=   2.922339654e+02        (936; 0)
# Time used: 11980.5 secs.  Memory used: 184.4 Mb.
# + 69889: mip =     not found yet >=   2.922339654e+02        (937; 0)
# + 69890: mip =     not found yet >=   2.922339654e+02        (938; 0)
# + 69891: mip =     not found yet >=   2.922339654e+02        (939; 0)
# + 69892: mip =     not found yet >=   2.922339654e+02        (940; 0)
# + 69893: mip =     not found yet >=   2.922339654e+02        (941; 0)
# + 69894: mip =     not found yet >=   2.922339654e+02        (942; 0)
# + 69895: mip =     not found yet >=   2.922339654e+02        (943; 0)
# Time used: 12042.1 secs.  Memory used: 184.5 Mb.
# + 69896: mip =     not found yet >=   2.922339654e+02        (944; 0)
# + 69897: mip =     not found yet >=   2.922339654e+02        (945; 0)
# + 69900: mip =     not found yet >=   2.922339654e+02        (946; 0)
# + 69903: mip =     not found yet >=   2.922339654e+02        (947; 0)
# + 69906: mip =     not found yet >=   2.922339654e+02        (948; 0)
# + 69909: mip =     not found yet >=   2.922339654e+02        (949; 0)
# + 69911: mip =     not found yet >=   2.922339654e+02        (950; 0)
# Time used: 12102.4 secs.  Memory used: 184.5 Mb.
# + 69913: mip =     not found yet >=   2.922339654e+02        (951; 0)
# + 69915: mip =     not found yet >=   2.922339654e+02        (952; 0)
# + 69917: mip =     not found yet >=   2.922339654e+02        (953; 0)
# + 69918: mip =     not found yet >=   2.922339654e+02        (954; 0)
# + 69919: mip =     not found yet >=   2.922339654e+02        (955; 0)
# + 69921: mip =     not found yet >=   2.922339654e+02        (956; 0)
# + 69922: mip =     not found yet >=   2.922339654e+02        (957; 0)
# + 69924: mip =     not found yet >=   2.922339654e+02        (958; 0)
# Time used: 12170.4 secs.  Memory used: 184.5 Mb.
# + 69927: mip =     not found yet >=   2.922339654e+02        (959; 0)
# + 69930: mip =     not found yet >=   2.922339654e+02        (960; 0)
# + 69933: mip =     not found yet >=   2.922339654e+02        (961; 0)
# + 69935: mip =     not found yet >=   2.922339654e+02        (962; 0)
# + 69936: mip =     not found yet >=   2.922339654e+02        (963; 0)
# + 69937: mip =     not found yet >=   2.922339654e+02        (964; 0)
# + 69938: mip =     not found yet >=   2.922339654e+02        (965; 0)
# + 69939: mip =     not found yet >=   2.922339654e+02        (966; 0)
# Time used: 12238.5 secs.  Memory used: 184.5 Mb.
# + 69940: mip =     not found yet >=   2.922339654e+02        (967; 0)
# + 69941: mip =     not found yet >=   2.922339654e+02        (968; 0)
# + 69942: mip =     not found yet >=   2.922339654e+02        (969; 0)
# + 69943: mip =     not found yet >=   2.922339654e+02        (970; 0)
# + 69944: mip =     not found yet >=   2.922339654e+02        (971; 0)
# + 69945: mip =     not found yet >=   2.922339654e+02        (972; 0)
# + 69947: mip =     not found yet >=   2.922339654e+02        (973; 0)
# + 69947: mip =     not found yet >=   2.922339654e+02        (974; 0)
# Time used: 12305.9 secs.  Memory used: 184.5 Mb.
# + 69947: mip =     not found yet >=   2.922339654e+02        (975; 0)
# + 69948: mip =     not found yet >=   2.922339654e+02        (976; 0)
# + 69949: mip =     not found yet >=   2.922339654e+02        (977; 0)
# + 69950: mip =     not found yet >=   2.922339654e+02        (978; 0)
# + 69951: mip =     not found yet >=   2.922339654e+02        (979; 0)
# + 69951: mip =     not found yet >=   2.922339654e+02        (980; 0)
# + 69951: mip =     not found yet >=   2.922339654e+02        (981; 0)
# Time used: 12366.1 secs.  Memory used: 184.5 Mb.
# + 69951: mip =     not found yet >=   2.922339654e+02        (982; 0)
# + 69951: mip =     not found yet >=   2.922339654e+02        (983; 0)
# + 69956: mip =     not found yet >=   2.922339654e+02        (984; 0)
# + 69960: mip =     not found yet >=   2.922339654e+02        (985; 0)
# + 69962: mip =     not found yet >=   2.922339654e+02        (986; 0)
# + 69965: mip =     not found yet >=   2.922339654e+02        (987; 0)
# + 69967: mip =     not found yet >=   2.922339654e+02        (988; 0)
# + 69971: mip =     not found yet >=   2.922339654e+02        (989; 0)
# Time used: 12434.1 secs.  Memory used: 184.5 Mb.
# + 69973: mip =     not found yet >=   2.922339654e+02        (990; 0)
# + 69974: mip =     not found yet >=   2.922339654e+02        (991; 0)
# + 69975: mip =     not found yet >=   2.922339654e+02        (992; 0)
# + 69976: mip =     not found yet >=   2.922339654e+02        (993; 0)
# + 69977: mip =     not found yet >=   2.922339654e+02        (994; 0)
# + 69979: mip =     not found yet >=   2.922339654e+02        (995; 0)
# + 69981: mip =     not found yet >=   2.922339654e+02        (996; 0)
# + 69983: mip =     not found yet >=   2.922339654e+02        (997; 0)
# Time used: 12502.2 secs.  Memory used: 184.5 Mb.
# + 69986: mip =     not found yet >=   2.922339654e+02        (998; 0)
# + 69988: mip =     not found yet >=   2.922339654e+02        (999; 0)
# + 69990: mip =     not found yet >=   2.922339654e+02        (1000; 0)
# + 69990: mip =     not found yet >=   2.922339654e+02        (1001; 0)
# + 69990: mip =     not found yet >=   2.922339654e+02        (1002; 0)
# + 69990: mip =     not found yet >=   2.922339654e+02        (1003; 0)
# + 69990: mip =     not found yet >=   2.922339654e+02        (1004; 0)
# + 69991: mip =     not found yet >=   2.922339654e+02        (1005; 0)
# Time used: 12568.4 secs.  Memory used: 184.5 Mb.
# + 69996: mip =     not found yet >=   2.922339654e+02        (1006; 0)
# + 70000: mip =     not found yet >=   2.922339654e+02        (1007; 0)
# + 70008: mip =     not found yet >=   2.922339654e+02        (1008; 0)
# + 70009: mip =     not found yet >=   2.922339654e+02        (1009; 0)
# + 70012: mip =     not found yet >=   2.922339654e+02        (1010; 0)
# + 70015: mip =     not found yet >=   2.922339654e+02        (1011; 0)
# + 70018: mip =     not found yet >=   2.922339654e+02        (1012; 0)
# + 70020: mip =     not found yet >=   2.922339654e+02        (1013; 0)
# Time used: 12635.1 secs.  Memory used: 184.5 Mb.
# + 70022: mip =     not found yet >=   2.922339654e+02        (1014; 0)
# + 70024: mip =     not found yet >=   2.922339654e+02        (1015; 0)
# + 70026: mip =     not found yet >=   2.922339654e+02        (1016; 0)
# + 70026: mip =     not found yet >=   2.922339654e+02        (1017; 0)
# + 70028: mip =     not found yet >=   2.922339654e+02        (1018; 0)
# + 70028: mip =     not found yet >=   2.922339654e+02        (1019; 0)
# + 70029: mip =     not found yet >=   2.922339654e+02        (1020; 0)
# + 70030: mip =     not found yet >=   2.922339654e+02        (1021; 0)
# Time used: 12700.6 secs.  Memory used: 184.5 Mb.
# + 70031: mip =     not found yet >=   2.922339654e+02        (1022; 0)
# + 70032: mip =     not found yet >=   2.922339654e+02        (1023; 0)
# + 70033: mip =     not found yet >=   2.922339654e+02        (1024; 0)
# + 70036: mip =     not found yet >=   2.922339654e+02        (1025; 0)
# + 70037: mip =     not found yet >=   2.922339654e+02        (1026; 0)
# + 70039: mip =     not found yet >=   2.922339654e+02        (1027; 0)
# + 70040: mip =     not found yet >=   2.922339654e+02        (1028; 0)
# + 70041: mip =     not found yet >=   2.922339654e+02        (1029; 0)
# Time used: 12766.7 secs.  Memory used: 184.5 Mb.
# + 70042: mip =     not found yet >=   2.922339654e+02        (1030; 0)
# + 70043: mip =     not found yet >=   2.922339654e+02        (1031; 0)
# + 70044: mip =     not found yet >=   2.922339654e+02        (1032; 0)
# + 70045: mip =     not found yet >=   2.922339654e+02        (1033; 0)
# + 70046: mip =     not found yet >=   2.922339654e+02        (1034; 0)
# + 70047: mip =     not found yet >=   2.922339654e+02        (1035; 0)
# + 70048: mip =     not found yet >=   2.922339654e+02        (1036; 0)
# + 70049: mip =     not found yet >=   2.922339654e+02        (1037; 0)
# Time used: 12832.5 secs.  Memory used: 184.5 Mb.
# + 70050: mip =     not found yet >=   2.922339654e+02        (1038; 0)
# + 70051: mip =     not found yet >=   2.922339654e+02        (1039; 0)
# + 70052: mip =     not found yet >=   2.922339654e+02        (1040; 0)
# + 70053: mip =     not found yet >=   2.922339654e+02        (1041; 0)
# + 70054: mip =     not found yet >=   2.922339654e+02        (1042; 0)
# + 70055: mip =     not found yet >=   2.922339654e+02        (1043; 0)
# + 70055: mip =     not found yet >=   2.922339654e+02        (1044; 0)
# + 70056: mip =     not found yet >=   2.922339654e+02        (1045; 0)
# Time used: 12898.7 secs.  Memory used: 184.5 Mb.
# + 70056: mip =     not found yet >=   2.922339654e+02        (1046; 0)
# + 70059: mip =     not found yet >=   2.922339654e+02        (1047; 0)
# + 70062: mip =     not found yet >=   2.922339654e+02        (1048; 0)
# + 70065: mip =     not found yet >=   2.922339654e+02        (1049; 0)
# + 70067: mip =     not found yet >=   2.922339654e+02        (1050; 0)
# + 70068: mip =     not found yet >=   2.922339654e+02        (1051; 0)
# + 70068: mip =     not found yet >=   2.922339654e+02        (1052; 0)
# + 70070: mip =     not found yet >=   2.922339654e+02        (1053; 0)
# Time used: 12964.5 secs.  Memory used: 184.5 Mb.
# + 70071: mip =     not found yet >=   2.922339654e+02        (1054; 0)
# + 70072: mip =     not found yet >=   2.922339654e+02        (1055; 0)
# + 70074: mip =     not found yet >=   2.922339654e+02        (1056; 0)
# + 70076: mip =     not found yet >=   2.922339654e+02        (1057; 0)
# + 70077: mip =     not found yet >=   2.922339654e+02        (1058; 0)
# + 70078: mip =     not found yet >=   2.922339654e+02        (1059; 0)
# + 70079: mip =     not found yet >=   2.922339654e+02        (1060; 0)
# + 70081: mip =     not found yet >=   2.922339654e+02        (1061; 0)
# Time used: 13029.4 secs.  Memory used: 184.5 Mb.
# + 70085: mip =     not found yet >=   2.922339654e+02        (1062; 0)
# + 70087: mip =     not found yet >=   2.922339654e+02        (1063; 0)
# + 70090: mip =     not found yet >=   2.922339654e+02        (1064; 0)
# + 70091: mip =     not found yet >=   2.922339654e+02        (1065; 0)
# + 70092: mip =     not found yet >=   2.922339654e+02        (1066; 0)
# Process ForkServerProcess-3:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/enzo/Desktop/FleetRL/venv/lib/python3.10/site-packages/stable_baselines3/common/vec_env/subproc_vec_env.py", line 34, in _worker
#     cmd, data = remote.recv()
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[78], line 2
#       1 opt = pyo.SolverFactory('glpk', keepfiles=True, tmpdir='./tmp_glpk/')
# ----> 2 res = opt.solve(model, tee=True)
#       3 print(res)
#
# File ~/Desktop/FleetRL/venv/lib/python3.10/site-packages/pyomo/opt/base/solvers.py:609, in OptSolver.solve(self, *args, **kwds)
#     606 if not _model is None:
#     607     self._initialize_callbacks(_model)
# --> 609 _status = self._apply_solver()
#     610 if hasattr(self, '_transformation_data'):
#     611     del self._transformation_data
#
# File ~/Desktop/FleetRL/venv/lib/python3.10/site-packages/pyomo/opt/solver/shellcmd.py:267, in SystemCallSolver._apply_solver(self)
#     264         print("Solver problem files: %s" % str(self._problem_files))
#     266 sys.stdout.flush()
# --> 267 self._rc, self._log = self._execute_command(self._command)
#     268 sys.stdout.flush()
#     269 return Bunch(rc=self._rc, log=self._log)
#
# File ~/Desktop/FleetRL/venv/lib/python3.10/site-packages/pyomo/opt/solver/shellcmd.py:335, in SystemCallSolver._execute_command(self, command)
#     333 try:
#     334     with TeeStream(*ostreams) as t:
# --> 335         results = subprocess.run(
#     336             command.cmd,
#     337             input=_input,
#     338             env=command.env,
#     339             stdout=t.STDOUT,
#     340             stderr=t.STDERR,
#     341             timeout=timeout,
#     342             universal_newlines=True,
#     343             cwd=command.cwd if "cwd" in command else None,
#     344         )
#     345         t.STDOUT.flush()
#     346         t.STDERR.flush()
#
# File /usr/lib/python3.10/subprocess.py:503, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
# --> 503         stdout, stderr = process.communicate(input, timeout=timeout)
#     504     except TimeoutExpired as exc:
#     505         process.kill()
#
# File /usr/lib/python3.10/subprocess.py:1144, in Popen.communicate(self, input, timeout)
#    1142         stderr = self.stderr.read()
#    1143         self.stderr.close()
# -> 1144     self.wait()
#    1145 else:
#    1146     if timeout is not None:
#
# File /usr/lib/python3.10/subprocess.py:1207, in Popen.wait(self, timeout)
#    1205     endtime = _time() + timeout
#    1206 try:
# -> 1207     return self._wait(timeout=timeout)
#    1208 except KeyboardInterrupt:
#    1209     # https://bugs.python.org/issue25942
#    1210     # The first keyboard interrupt waits briefly for the child to
#    1211     # exit under the common assumption that it also received the ^C
#    1212     # generated SIGINT and will exit rapidly.
#    1213     if timeout is not None:
#
# File /usr/lib/python3.10/subprocess.py:1941, in Popen._wait(self, timeout)
#    1939 if self.returncode is not None:
#    1940     break  # Another thread waited.
# -> 1941 (pid, sts) = self._try_wait(0)
#    1942 # Check the pid and loop as waitpid has been known to
#    1943 # return 0 even without WNOHANG in odd situations.
#    1944 # http://bugs.python.org/issue14396.
#    1945 if pid == self.pid:
#
# File /usr/lib/python3.10/subprocess.py:1899, in Popen._try_wait(self, wait_flags)
#    1897 """All callers to this function MUST hold self._waitpid_lock."""
#    1898 try:
# -> 1899     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1900 except ChildProcessError:
#    1901     # This happens if SIGCLD is set to be ignored or waiting
#    1902     # for child processes has otherwise been disabled for our
#    1903     # process.  This child is dead, we can't get the status.
#    1904     pid = self.pid
#
# KeyboardInterrupt:

# %%
actions = [model.charging_signal[i].value + model.discharging_signal[i].value for i in range(len(df))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 actions = [model.charging_signal[i].value + model.discharging_signal[i].value for i in range(len(df))]
#
# Cell In[79], line 1, in <listcomp>(.0)
# ----> 1 actions = [model.charging_signal[i].value + model.discharging_signal[i].value for i in range(len(df))]
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %%
plt.plot(sorted(actions))
plt.show()

# %%
actions = pd.DataFrame({"action": actions})

# %%
actions.index = pd.date_range(start="2020-01-01 00:00", end="2020-12-30 23:59", freq="15T")

# %%
for i in range(len(actions)):
    actions.loc[i, "hid"] = actions.index[i].hour + actions.index[i].minute/60

# %%
actions.groupby("hid").mean().reset_index().plot()
plt.show()

# %%
import datetime as dt
import numpy as np
import math
import matplotlib.pyplot as plt
from typing import Literal

from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3 import PPO, TD3
from stable_baselines3.common.vec_env import VecNormalize, SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env

from FleetRL.fleet_env.fleet_environment import FleetEnv

import pandas as pd
import pyomo.environ as pyo
#import gurobipy

if __name__ == "__main__":

    # define parameters here for easier change
    n_steps = 8600
    n_episodes = 1
    n_evs = 1
    n_envs = 1
    time_steps_per_hour = 4
    use_case: str = "lmd"  # for file name
    scenario: Literal["arb", "real"] = "arb"
    
    # environment arguments
    env_kwargs = {"schedule_name": "lmd_sched_single_eval.csv",
                  "building_name": "load_lmd.csv",
                  "price_name": "spot_2021_new.csv",
                  "tariff_name": "spot_2021_new_tariff.csv",
                  "use_case": "lmd",
                  "include_building": True,
                  "include_pv": True,
                  "time_picker": "static",
                  "deg_emp": False,
                  "include_price": True,
                  "ignore_price_reward": False,
                  "ignore_invalid_penalty": True,
                  "ignore_overcharging_penalty": True,
                  "ignore_overloading_penalty": False,
                  "episode_length": n_steps,
                  "normalize_in_env": False,
                  "verbose": 0,
                  "aux": True,
                  "log_data": True,
                  "calculate_degradation": True
                  }
    
    if scenario == "real":
        env_kwargs["spot_markup"] = 10
        env_kwargs["spot_mul"] = 1.5
        env_kwargs["feed_in_ded"] = 0.25
    elif scenario == "arb":
        env_kwargs["spot_markup"] = 0
        env_kwargs["spot_mul"] = 1
        env_kwargs["feed_in_ded"] = 0
    
    lin_vec_env = make_vec_env(FleetEnv,
                               n_envs=n_envs,
                               vec_env_cls=SubprocVecEnv,
                               env_kwargs=env_kwargs)
    
    lin_norm_vec_env = VecNormalize(venv=lin_vec_env,
                                    norm_obs=True,
                                    norm_reward=True,
                                    training=True,
                                    clip_reward=10.0)
    
    env = FleetEnv(use_case=use_case,
                   schedule_name=env_kwargs["schedule_name"],
                   tariff_name=env_kwargs["tariff_name"],
                   price_name=env_kwargs["price_name"],
                   episode_length=n_steps,
                   time_picker=env_kwargs["time_picker"],
                   building_name=env_kwargs["building_name"])
    
    # reading the input file as a pandas DataFrame
    df: pd.DataFrame = env.db
    
    # Extracting information from the df
    ev_data = df["There"]
    building_data = df["load"]  # building load in kW
    
    if scenario == "arb":
        price_data = np.multiply(np.add(df["DELU"], env.ev_conf.fixed_markup), env.ev_conf.variable_multiplier) / 1000
        tariff_data = np.multiply(df["tariff"], 1-env.ev_conf.feed_in_deduction) / 1000
    elif scenario == "real":
        price_data = np.multiply(np.add(df["DELU"], 0), 1) / 1000  # price in EUR/kWh
        tariff_data = np.multiply(np.add(df["DELU"], 0), 1) / 1000  # price in EUR/kWh
    
    pv_data = df["pv"]  # pv power in kW
    soc_on_return = df["SOC_on_return"]
    
    battery_capacity = env.ev_conf.init_battery_cap  # EV batt size in kWh
    p_trafo = env.load_calculation.grid_connection  # Transformer rating in kW
    
    charging_eff = env.ev_conf.charging_eff  # charging losses
    discharging_eff = env.ev_conf.discharging_eff  # discharging losses
    
    init_soc = env.ev_conf.def_soc  # init SoC
    
    evse_max_power = env.load_calculation.evse_max_power  # kW, max rating of the charger
    
    # create pyomo model
    model = pyo.ConcreteModel(name="sc_pyomo")
    
    model.timestep = pyo.Set(initialize=range(len(df)))
    model.time_batt = pyo.Set(initialize=range(0, len(df)+1))
    
    # model parameters
    model.building_load = pyo.Param(model.timestep, initialize={i: building_data[i] for i in range(len(df))})
    model.pv = pyo.Param(model.timestep, initialize={i: pv_data[i] for i in range(len(df))})
    model.ev_availability = pyo.Param(model.timestep, initialize={i: ev_data[i] for i in range(len(df))})
    model.price = pyo.Param(model.timestep, initialize={i: price_data[i] for i in range(len(df))})
    model.tariff = pyo.Param(model.timestep, initialize={i: tariff_data[i] for i in range(len(df))})
    
    # decision variables
    # this assumes only charging, I could also make bidirectional later
    model.soc = pyo.Var(model.time_batt, bounds=(0, env.ev_conf.target_soc))
    model.charging_signal = pyo.Var(model.timestep, within=pyo.NonNegativeReals, bounds=(0,1))
    model.discharging_signal = pyo.Var(model.timestep, within=pyo.NonPositiveReals, bounds=(-1,0))
    model.positive_action = pyo.Var(model.timestep, within=pyo.Binary)
    model.used_pv = pyo.Var(model.timestep, within=pyo.NonNegativeReals)
    
    def grid_limit(m, i):
        return ((m.charging_signal[i] + m.discharging_signal[i]) * evse_max_power
                + m.building_load[i] - m.pv[i] <= p_trafo)
    
    def mutual_exclusivity_charging(m, i):
        return m.charging_signal[i] <= model.positive_action[i]
    
    def mutual_exclusivity_discharging(m, i):
        return m.discharging_signal[i] >= (model.positive_action[i] - 1)
    
    def pv_use(m, i):
        return m.used_pv[i] <= m.charging_signal[i] * evse_max_power
    
    def pv_constraint(m, i):
        return m.used_pv[i] <= m.pv[i]
    
    def no_charge_when_no_car(m, i):
        if m.ev_availability[i] == 0:
            return m.charging_signal[i] == 0
        else:
            return pyo.Constraint.Feasible
    
    def no_discharge_when_no_car(m, i):
        if m.ev_availability[i] == 0:
            return m.discharging_signal[i] == 0
        else:
            return pyo.Constraint.Feasible
    
    def soc_rules(m, i):
        #last time step
        if i == len(df)-1:
            return (m.soc[i+1]
                    == m.soc[i] + (m.charging_signal[i]*charging_eff + m.discharging_signal[i])
                    * evse_max_power * 1 / time_steps_per_hour / battery_capacity)
    
        # new arrival
        elif (m.ev_availability[i] == 0) and (m.ev_availability[i+1] == 1):
            return m.soc[i+1] == soc_on_return[i+1]
    
        # departure in next time step
        elif (m.ev_availability[i] == 1) and (m.ev_availability[i+1] == 0):
            return m.soc[i] == env.ev_conf.target_soc
    
        else:
            return pyo.Constraint.Feasible
    
    def charging_dynamics(m, i):
        #last time step
        if i == len(df)-1:
            return (m.soc[i+1]
                    == m.soc[i] + (m.charging_signal[i]*charging_eff + m.discharging_signal[i])
                    * evse_max_power * 1 / time_steps_per_hour / battery_capacity)
    
        # charging
        if (m.ev_availability[i] == 1) and (m.ev_availability[i+1] == 1):
            return (m.soc[i+1]
                    == m.soc[i] + (m.charging_signal[i]*charging_eff + m.discharging_signal[i])
                    * evse_max_power * 1 / time_steps_per_hour / battery_capacity)
    
        elif (m.ev_availability[i] == 1) and (m.ev_availability[i+1] == 0):
            return m.soc[i+1] == 0
    
        elif m.ev_availability[i] == 0:
            return m.soc[i] == 0
    
        else:
            return pyo.Constraint.Feasible
    
    def max_charging_limit(m, i):
        return m.charging_signal[i]*evse_max_power <= evse_max_power * ev_data[i]
    
    def max_discharging_limit(m, i):
        return m.discharging_signal[i]*evse_max_power*-1 <= evse_max_power * ev_data[i]
    
    def first_soc(m):
        return m.soc[0] == init_soc
    
    # constraints
    model.cs1 = pyo.Constraint(rule=first_soc)
    model.cs2 = pyo.Constraint(model.timestep, rule=grid_limit)
    model.cs3 = pyo.Constraint(model.timestep, rule=max_charging_limit)
    model.cs4 = pyo.Constraint(model.timestep, rule=max_discharging_limit)
    model.cs5 = pyo.Constraint(model.timestep, rule=soc_rules)
    model.cs6 = pyo.Constraint(model.timestep, rule=charging_dynamics)
    model.cs8 = pyo.Constraint(model.timestep, rule=mutual_exclusivity_charging)
    model.cs9 = pyo.Constraint(model.timestep, rule=mutual_exclusivity_discharging)
    model.cs10 = pyo.Constraint(model.timestep, rule=no_charge_when_no_car)
    model.cs11 = pyo.Constraint(model.timestep, rule=no_discharge_when_no_car)
    model.cs12 = pyo.Constraint(model.timestep, rule=pv_use)
    model.cs13 = pyo.Constraint(model.timestep, rule=pv_constraint)
    
    timestep_set = pyo.RangeSet(0, len(df)-1)
    
    def obj_fun(m):
        return (sum([((m.charging_signal[i] * evse_max_power - m.used_pv[i]) / time_steps_per_hour) * m.price[i] +
                     ((m.discharging_signal[i] * evse_max_power * discharging_eff) / time_steps_per_hour) * m.tariff[i]
                     for i in m.timestep]))
    
    model.obj = pyo.Objective(rule=obj_fun, sense=pyo.minimize)
    
    opt = pyo.SolverFactory('gurobi', solver_io="python")#, executable="/home/enzo/Downloads/gurobi10.0.2_linux64/gurobi1002/linux64/")

    res = opt.solve(model, tee=True)
    print(res)

    actions = [model.charging_signal[i].value + model.discharging_signal[i].value for i in range(len(df))]
    
    actions = pd.DataFrame({"action": actions})
    
    actions.index = pd.date_range(start="2020-01-01 00:00", end="2020-12-30 23:59", freq="15T")

    actions["hid"] = actions.index.dt.hour + actions.index.dt.minute/60
    
    actions.groupby("hid").mean().reset_index().plot()
    plt.show()

    start_time = lin_norm_vec_env.env_method("get_start_time")[0]
    end_time = start_time + dt.timedelta(hours=n_steps)
    env_actions = actions.loc[(actions.index >= start_time) & (actions.index <= end_time)]

    lin_norm_vec_env.reset()

    for i in range(n_steps*time_steps_per_hour):
        env.step([np.ones(n_evs) * env_actions[i]])

    lin_log: pd.DataFrame = lin_norm_vec_env.env_method("get_log")[0]

    lin_log.reset_index(drop=True, inplace=True)
    lin_log = lin_log.iloc[0:-2]

    # night_log.to_csv(f"log_dumb_{use_case}_{n_evs}.csv")
    real_power_lin = []
    for i in range(lin_log.__len__()):
        lin_log.loc[i, "hour_id"] = (lin_log.loc[i, "Time"].hour + lin_log.loc[i, "Time"].minute / 60)

    mean_per_hid_lin = lin_log.groupby("hour_id").mean()["Charging energy"].reset_index(drop=True)
    mean_all_lin = []
    for i in range(mean_per_hid_lin.__len__()):
        mean_all_lin.append(np.mean(mean_per_hid_lin[i]))

    mean = pd.DataFrame()
    mean["Distributed charging"] = np.multiply(mean_all_lin, 4)

    mean.plot()

    plt.xticks([0,8,16,24,32,40,48,56,64,72,80,88]
               ,["00:00","02:00","04:00","06:00","08:00","10:00","12:00","14:00","16:00","18:00","20:00","22:00"],
               rotation=45)

    plt.legend()
    plt.grid(alpha=0.2)

    plt.ylabel("Charging power in kW")
    max = lin_log.loc[0, "Observation"][-10]
    plt.ylim([-max * 1.2, max * 1.2])

    plt.show()
# Out:
# WARNING: The gurobipy module (an optional Pyomo dependency) failed to import:
# ModuleNotFoundError: No module named 'gurobipy'
# ---------------------------------------------------------------------------
# ApplicationError                          Traceback (most recent call last)
# Cell In[15], line 230
#     226 model.obj = pyo.Objective(rule=obj_fun, sense=pyo.minimize)
#     228 opt = pyo.SolverFactory('gurobi', solver_io="python")#, executable="/home/enzo/Downloads/gurobi10.0.2_linux64/gurobi1002/linux64/")
# --> 230 res = opt.solve(model, tee=True)
#     231 print(res)
#     233 actions = [model.charging_signal[i].value + model.discharging_signal[i].value for i in range(len(df))]
#
# File ~/Desktop/FleetRL/venv/lib/python3.10/site-packages/pyomo/solvers/plugins/solvers/direct_solver.py:75, in DirectSolver.solve(self, *args, **kwds)
#      72 def solve(self, *args, **kwds):
#      73     """Solve the problem"""
# ---> 75     self.available(exception_flag=True)
#      76     #
#      77     # If the inputs are models, then validate that they have been
#      78     # constructed! Collect suffix names to try and import from solution.
#      79     #
#      80     _model = None
#
# File ~/Desktop/FleetRL/venv/lib/python3.10/site-packages/pyomo/solvers/plugins/solvers/gurobi_direct.py:215, in GurobiDirect.available(self, exception_flag)
#     213     if exception_flag:
#     214         gurobipy.log_import_warning(logger=__name__)
# --> 215         raise ApplicationError(
#     216             "No Python bindings available for %s solver plugin" % (type(self),)
#     217         )
#     218     return False
#     220 # Ensure environment is started to check for a valid license
#
# ApplicationError: No Python bindings available for <class 'pyomo.solvers.plugins.solvers.gurobi_direct.GurobiDirect'> solver plugin

# %%
# %cd /home/enzo/Downloads/gurobi10.0.2_linux64/gurobi1002/linux64/
# Out:
# /home/enzo/Downloads/gurobi10.0.2_linux64/gurobi1002/linux64

# %%
pip install -e .
# Out:
# Obtaining file:///home/enzo/Downloads/gurobi10.0.2_linux64/gurobi1002/linux64
#   Preparing metadata (setup.py) ... done
# Installing collected packages: gurobipy
#   Attempting uninstall: gurobipy
#     Found existing installation: gurobipy 10.0.2
#     Uninstalling gurobipy-10.0.2:
#       Successfully uninstalled gurobipy-10.0.2
#   Running setup.py develop for gurobipy
# Successfully installed gurobipy-10.0.2
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
