# %%
import numpy as np
import time
import os

import FleetRL
from FleetRL.fleet_env.fleet_environment import FleetEnv

from stable_baselines3 import TD3
from stable_baselines3.common.vec_env import VecNormalize, SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import EvalCallback, ProgressBarCallback

from pink import PinkNoiseDist, PinkActionNoise

# %%
run_name = "td3_full_vecnorm_clip5"

# %%
time_now = int(time.time())
trained_agents_dir = f"./trained/vec_TD3-{time_now}-{run_name}"
logs_dir = f"./logs/vec_TD3-{time_now}-{run_name}"

if not os.path.exists(trained_agents_dir):
    os.makedirs(trained_agents_dir)

if not os.path.exists(logs_dir):
    os.makedirs(logs_dir)

# %%
n_cpu = 4
train_vec_env = make_vec_env(FleetEnv,
                             n_envs=n_cpu,
                             vec_env_cls=SubprocVecEnv,
                             env_kwargs={
                                 "schedule_name": "lmd_sched_single.csv",
                                 "building_name": "load_lmd.csv",
                                 "include_building": True,
                                 "include_pv": True,
                                 "static_time_picker": False,
                                 "deg_emp": False,
                                 "include_price": True,
                                 "ignore_price_reward": False,
                                 "ignore_invalid_penalty": False,
                                 "ignore_overcharging_penalty": False,
                                 "ignore_overloading_penalty": False,
                                 "episode_length": 48,
                                 "normalize_in_env": False,
                                 "verbose": 0
                             })

# %%
train_norm_vec_env = VecNormalize(venv=train_vec_env, norm_obs=True, norm_reward=True, training=True, clip_reward=5)

# %%
eval_vec_env = make_vec_env(FleetEnv,
                            n_envs=1,
                            vec_env_cls=SubprocVecEnv,
                            env_kwargs={
                                "schedule_name": "lmd_sched_single.csv",
                                "building_name": "load_lmd.csv",
                                "include_building": True,
                                "include_pv": True,
                                "static_time_picker": False,
                                "deg_emp": False,
                                "include_price": True,
                                "ignore_price_reward": False,
                                "ignore_invalid_penalty": False,
                                "ignore_overcharging_penalty": False,
                                "ignore_overloading_penalty": False,
                                "episode_length": 48,
                                "normalize_in_env": False,
                                "verbose": 1
                            })

# %%
eval_norm_vec_env = VecNormalize(venv=eval_vec_env,
                                 norm_obs=True,
                                 norm_reward=True,
                                 training=True,
                                 clip_reward=5)

# %%
eval_callback = EvalCallback(eval_env=eval_norm_vec_env,
                             warn=True,
                             verbose=1,
                             deterministic=True,
                             eval_freq=max(5000 // n_cpu, 1),
                             n_eval_episodes=5,
                             render=False,
                             )

# %%
n_actions = train_norm_vec_env.action_space.shape[-1]
param_noise = None
noise_scale = 0.3
seq_len = 48 * 4
action_noise = PinkActionNoise(noise_scale, seq_len, n_actions)

# %%
model = TD3(policy="MlpPolicy",
            env=train_norm_vec_env,
            verbose=0,
            train_freq=(1, "step"),
            learning_rate=0.005,
            learning_starts=20000,
            gamma=0.99,
            batch_size=128,
            buffer_size=500000,
            tensorboard_log="./tb_log",
            action_noise=action_noise
            )

# %%
model.learn(100, callback=eval_callback)
# Out:
# Invalid action, penalty given.
# Timestep: 2020-02-08 10:15:00
# Price: 0.02763 €/kWh
# SOC: [0.], Time left: [0.] hours
# Action taken: [0.1966399]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 16.191453600000006 kW.
# Reward signal: -0.9214378187311678
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 10:30:00
# Price: 0.02763 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.19396913]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 16.191453600000006 kW.
# Reward signal: -0.9213334962426513
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 10:45:00
# Price: 0.02763 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.19138634]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 16.191453600000006 kW.
# Reward signal: -0.921233967075612
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 11:00:00
# Price: 0.02801 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.16577017]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 15.053953600000007 kW.
# Reward signal: -0.7959232914963951
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 11:15:00
# Price: 0.02801 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.16386652]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 15.053953600000007 kW.
# Reward signal: -0.7958605401036666
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 11:30:00
# Price: 0.02801 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.16204047]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 15.053953600000007 kW.
# Reward signal: -0.7958010279259272
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 11:45:00
# Price: 0.02801 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.16027725]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 15.053953600000007 kW.
# Reward signal: -0.7957441960726742
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 12:00:00
# Price: 0.026420000000000003 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.11268592]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 3.5263178999999987 kW.
# Reward signal: -0.044792024391271335
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 12:15:00
# Price: 0.026420000000000003 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.11136889]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 3.5263178999999987 kW.
# Reward signal: -0.044762515829442275
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 12:30:00
# Price: 0.026420000000000003 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.11010098]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 3.5263178999999987 kW.
# Reward signal: -0.044734435441913814
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 12:45:00
# Price: 0.026420000000000003 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.10887218]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 3.5263178999999987 kW.
# Reward signal: -0.04470752781515243
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 13:00:00
# Price: 0.02476 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.08224177]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 24.328953600000006 kW.
# Reward signal: -2.0723193123809116
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 13:15:00
# Price: 0.02476 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.08170509]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 24.328953600000006 kW.
# Reward signal: -2.072310513676822
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 13:30:00
# Price: 0.02476 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.08117878]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 24.328953600000006 kW.
# Reward signal: -2.0723019409515224
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 13:45:00
# Price: 0.02476 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.08066273]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 24.328953600000006 kW.
# Reward signal: -2.0722935890067866
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 14:00:00
# Price: 0.02453 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.09777558]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 33.516453600000006 kW.
# Reward signal: -3.000956006375078
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 14:15:00
# Price: 0.02453 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.09677434]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 33.516453600000006 kW.
# Reward signal: -3.000936527281971
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 14:30:00
# Price: 0.02453 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.09578693]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 33.516453600000006 kW.
# Reward signal: -3.000917513579226
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 14:45:00
# Price: 0.02453 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.0948199]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 33.516453600000006 kW.
# Reward signal: -3.00089908140758
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 15:00:00
# Price: 0.02416 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.07840979]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 41.5664536 kW.
# Reward signal: -3.0006148095323524
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 15:15:00
# Price: 0.02416 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.07729721]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 41.5664536 kW.
# Reward signal: -3.0005974858780973
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 15:30:00
# Price: 0.02416 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.07621181]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 41.5664536 kW.
# Reward signal: -3.0005808240000547
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 15:45:00
# Price: 0.02416 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.07515132]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 41.5664536 kW.
# Reward signal: -3.000564772153986
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 16:00:00
# Price: 0.02386 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.06859648]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 43.578953600000006 kW.
# Reward signal: -3.0004705477380766
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 16:15:00
# Price: 0.02386 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.06792426]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 43.578953600000006 kW.
# Reward signal: -3.000461370524505
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 16:30:00
# Price: 0.02386 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.06726229]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 43.578953600000006 kW.
# Reward signal: -3.0004524215912753
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 16:45:00
# Price: 0.02386 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.06660628]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 43.578953600000006 kW.
# Reward signal: -3.00044363969601
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 17:00:00
# Price: 0.02556 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.03764045]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.00014168036557435926
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 17:15:00
# Price: 0.02556 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.03732002]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.00013927837296847655
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 17:30:00
# Price: 0.02556 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.03700554]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.00013694102651840012
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 17:45:00
# Price: 0.02556 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.03669703]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.00013466720157708778
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 18:00:00
# Price: 0.028079999999999997 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.05650949]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.0003193323000459714
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 18:15:00
# Price: 0.028079999999999997 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.05597734]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.0003133463098720313
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 18:30:00
# Price: 0.028079999999999997 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.05545425]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.0003075174303376116
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 18:45:00
# Price: 0.028079999999999997 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.05493999]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.00030184019820467256
# ---------
#
#
# Invalid action, penalty given.
# Timestep: 2020-02-08 19:00:00
# Price: 0.033 €/kWh
# SOC: [0.0], Time left: [0.] hours
# Action taken: [0.0790441]
# Actual charging energy: 0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.0006247970317474483
# ---------
#
#
# Timestep: 2020-02-08 19:15:00
# Price: 0.033 €/kWh
# SOC: [0.6324463299709444], Time left: [35.75] hours
# Action taken: [-0.03059566]
# Actual charging energy: -0.08413806557655334 kWh
# Charging cost/revenue: 0.0027765561640262604 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.005553112328052521
# ---------
#
#
# Timestep: 2020-02-08 19:30:00
# Price: 0.033 €/kWh
# SOC: [0.6312683970528726], Time left: [35.5] hours
# Action taken: [-0.02958298]
# Actual charging energy: -0.08135318756103516 kWh
# Charging cost/revenue: 0.00268465518951416 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.00536931037902832
# ---------
#
#
# Timestep: 2020-02-08 19:45:00
# Price: 0.033 €/kWh
# SOC: [0.6301294524270181], Time left: [35.25] hours
# Action taken: [-0.0285098]
# Actual charging energy: -0.07840193808078766 kWh
# Charging cost/revenue: 0.0025872639566659928 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.0051745279133319855
# ---------
#
#
# Timestep: 2020-02-08 20:00:00
# Price: 0.034140000000000004 €/kWh
# SOC: [0.6290318252938871], Time left: [35.] hours
# Action taken: [-0.01340508]
# Actual charging energy: -0.03686398267745972 kWh
# Charging cost/revenue: 0.0012585363686084747 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.0025170727372169494
# ---------
#
#
# Timestep: 2020-02-08 20:15:00
# Price: 0.034140000000000004 €/kWh
# SOC: [0.6285157295364027], Time left: [34.75] hours
# Action taken: [-0.01346952]
# Actual charging energy: -0.03704117238521576 kWh
# Charging cost/revenue: 0.001264585625231266 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.002529171250462532
# ---------
#
#
# Timestep: 2020-02-08 20:30:00
# Price: 0.034140000000000004 €/kWh
# SOC: [0.6279971531230096], Time left: [34.5] hours
# Action taken: [-0.01353043]
# Actual charging energy: -0.037208691239356995 kWh
# Charging cost/revenue: 0.001270304718911648 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.002540609437823296
# ---------
#
#
# Timestep: 2020-02-08 20:45:00
# Price: 0.034140000000000004 €/kWh
# SOC: [0.6274762314456587], Time left: [34.25] hours
# Action taken: [-0.01360738]
# Actual charging energy: -0.037420302629470825 kWh
# Charging cost/revenue: 0.001277529131770134 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.002555058263540268
# ---------
#
#
# Timestep: 2020-02-08 21:00:00
# Price: 0.03549 €/kWh
# SOC: [0.6269523472088461], Time left: [34.] hours
# Action taken: [0.00727713]
# Actual charging energy: 0.020012110471725464 kWh
# Charging cost/revenue: -0.0007102298006415367 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.0014204596012830735
# ---------
#
#
# Timestep: 2020-02-08 21:15:00
# Price: 0.03549 €/kWh
# SOC: [0.6272325167554502], Time left: [33.75] hours
# Action taken: [0.00722039]
# Actual charging energy: 0.01985606551170349 kWh
# Charging cost/revenue: -0.000704691765010357 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.001409383530020714
# ---------
#
#
# Timestep: 2020-02-08 21:30:00
# Price: 0.03549 €/kWh
# SOC: [0.627510501672614], Time left: [33.5] hours
# Action taken: [0.0071919]
# Actual charging energy: 0.01977771520614624 kWh
# Charging cost/revenue: -0.0007019111126661302 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.0014038222253322603
# ---------
#
#
# Timestep: 2020-02-08 21:45:00
# Price: 0.03549 €/kWh
# SOC: [0.6277873896855001], Time left: [33.25] hours
# Action taken: [0.00695574]
# Actual charging energy: 0.01912829279899597 kWh
# Charging cost/revenue: -0.0006788631114363671 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.0013577262228727342
# ---------
#
#
# Timestep: 2020-02-08 22:00:00
# Price: 0.03843 €/kWh
# SOC: [0.628055185784686], Time left: [33.] hours
# Action taken: [0.02349079]
# Actual charging energy: 0.0645996630191803 kWh
# Charging cost/revenue: -0.002482565049827099 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.004965130099654198
# ---------
#
#
# Timestep: 2020-02-08 22:15:00
# Price: 0.03843 €/kWh
# SOC: [0.6289595810669545], Time left: [32.75] hours
# Action taken: [0.02174687]
# Actual charging energy: 0.059803903102874756 kWh
# Charging cost/revenue: -0.002298263996243477 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.004596527992486954
# ---------
#
#
# Timestep: 2020-02-08 22:30:00
# Price: 0.03843 €/kWh
# SOC: [0.6297968357103947], Time left: [32.5] hours
# Action taken: [0.02009702]
# Actual charging energy: 0.05526679754257202 kWh
# Charging cost/revenue: -0.0021239030295610428 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.0042478060591220855
# ---------
#
#
# Timestep: 2020-02-08 22:45:00
# Price: 0.03843 €/kWh
# SOC: [0.6305705708759907], Time left: [32.25] hours
# Action taken: [0.01857817]
# Actual charging energy: 0.051089972257614136 kWh
# Charging cost/revenue: -0.001963387633860111 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.003926775267720222
# ---------
#
#
# Timestep: 2020-02-08 23:00:00
# Price: 0.03489 €/kWh
# SOC: [0.6312858304875972], Time left: [32.] hours
# Action taken: [0.05802143]
# Actual charging energy: 0.15955892205238342 kWh
# Charging cost/revenue: -0.005567010790407658 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.011134021580815315
# ---------
#
#
# Timestep: 2020-02-08 23:15:00
# Price: 0.03489 €/kWh
# SOC: [0.6335196553963306], Time left: [31.75] hours
# Action taken: [0.0473386]
# Actual charging energy: 0.13018116354942322 kWh
# Charging cost/revenue: -0.0045420207962393756 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.009084041592478751
# ---------
#
#
# Timestep: 2020-02-08 23:30:00
# Price: 0.03489 €/kWh
# SOC: [0.6353421916860226], Time left: [31.5] hours
# Action taken: [0.03955925]
# Actual charging energy: 0.10878792405128479 kWh
# Charging cost/revenue: -0.0037956106701493263 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.0075912213402986525
# ---------
#
#
# Timestep: 2020-02-08 23:45:00
# Price: 0.03489 €/kWh
# SOC: [0.6368652226227406], Time left: [31.25] hours
# Action taken: [0.03431439]
# Actual charging energy: 0.09436458349227905 kWh
# Charging cost/revenue: -0.003292380318045616 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.006584760636091232
# ---------
#
#
# Timestep: 2020-02-09 00:00:00
# Price: 0.04167 €/kWh
# SOC: [0.6381863267916325], Time left: [31.] hours
# Action taken: [0.07882941]
# Actual charging energy: 0.2167808711528778 kWh
# Charging cost/revenue: -0.009033258900940418 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.018066517801880837
# ---------
#
#
# Timestep: 2020-02-09 00:15:00
# Price: 0.04167 €/kWh
# SOC: [0.6412212589877727], Time left: [30.75] hours
# Action taken: [0.06882322]
# Actual charging energy: 0.18926385045051575 kWh
# Charging cost/revenue: -0.007886624648272991 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.015773249296545982
# ---------
#
#
# Timestep: 2020-02-09 00:30:00
# Price: 0.04167 €/kWh
# SOC: [0.6438709528940799], Time left: [30.5] hours
# Action taken: [0.05983078]
# Actual charging energy: 0.16453465819358826 kWh
# Charging cost/revenue: -0.0068561592069268235 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.013712318413853647
# ---------
#
#
# Timestep: 2020-02-09 00:45:00
# Price: 0.04167 €/kWh
# SOC: [0.6461744381087902], Time left: [30.25] hours
# Action taken: [0.05186653]
# Actual charging energy: 0.14263296127319336 kWh
# Charging cost/revenue: -0.0059435154962539675 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.011887030992507935
# ---------
#
#
# Timestep: 2020-02-09 01:00:00
# Price: 0.038020000000000005 €/kWh
# SOC: [0.6481712995666149], Time left: [30.] hours
# Action taken: [0.05471325]
# Actual charging energy: 0.15046143531799316 kWh
# Charging cost/revenue: -0.0057205437707901 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.0114410875415802
# ---------
#
#
# Timestep: 2020-02-09 01:15:00
# Price: 0.038020000000000005 €/kWh
# SOC: [0.6502777596610668], Time left: [29.75] hours
# Action taken: [0.05094707]
# Actual charging energy: 0.14010444283485413 kWh
# Charging cost/revenue: -0.005326770916581154 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.010653541833162307
# ---------
#
#
# Timestep: 2020-02-09 01:30:00
# Price: 0.038020000000000005 €/kWh
# SOC: [0.6522392218607548], Time left: [29.5] hours
# Action taken: [0.04807663]
# Actual charging energy: 0.13221073150634766 kWh
# Charging cost/revenue: -0.005026652011871338 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.010053304023742675
# ---------
#
#
# Timestep: 2020-02-09 01:45:00
# Price: 0.038020000000000005 €/kWh
# SOC: [0.6540901721018436], Time left: [29.25] hours
# Action taken: [0.04563248]
# Actual charging energy: 0.12548932433128357 kWh
# Charging cost/revenue: -0.0047711041110754015 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.009542208222150803
# ---------
#
#
# Timestep: 2020-02-09 02:00:00
# Price: 0.03635 €/kWh
# SOC: [0.6558470226424816], Time left: [29.] hours
# Action taken: [0.04225814]
# Actual charging energy: 0.11620989441871643 kWh
# Charging cost/revenue: -0.004224229662120342 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.008448459324240685
# ---------
#
#
# Timestep: 2020-02-09 02:15:00
# Price: 0.03635 €/kWh
# SOC: [0.6574739611643436], Time left: [28.75] hours
# Action taken: [0.04038429]
# Actual charging energy: 0.11105680465698242 kWh
# Charging cost/revenue: -0.004036914849281311 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.008073829698562622
# ---------
#
#
# Timestep: 2020-02-09 02:30:00
# Price: 0.03635 €/kWh
# SOC: [0.6590287564295414], Time left: [28.5] hours
# Action taken: [0.03877187]
# Actual charging energy: 0.10662263631820679 kWh
# Charging cost/revenue: -0.0038757328301668166 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.007751465660333633
# ---------
#
#
# Timestep: 2020-02-09 02:45:00
# Price: 0.03635 €/kWh
# SOC: [0.6605214733379963], Time left: [28.25] hours
# Action taken: [0.03683341]
# Actual charging energy: 0.10129186511039734 kWh
# Charging cost/revenue: -0.0036819592967629435 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.007363918593525887
# ---------
#
#
# Timestep: 2020-02-09 03:00:00
# Price: 0.03472 €/kWh
# SOC: [0.6619395594495419], Time left: [28.] hours
# Action taken: [0.05862451]
# Actual charging energy: 0.16121739149093628 kWh
# Charging cost/revenue: -0.0055974678325653076 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.011194935665130615
# ---------
#
#
# Timestep: 2020-02-09 03:15:00
# Price: 0.03472 €/kWh
# SOC: [0.6641966029304149], Time left: [27.75] hours
# Action taken: [0.05499554]
# Actual charging energy: 0.15123772621154785 kWh
# Charging cost/revenue: -0.005250973854064942 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.010501947708129884
# ---------
#
#
# Timestep: 2020-02-09 03:30:00
# Price: 0.03472 €/kWh
# SOC: [0.6663139310973766], Time left: [27.5] hours
# Action taken: [0.05194294]
# Actual charging energy: 0.142843097448349 kWh
# Charging cost/revenue: -0.004959512343406677 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.009919024686813355
# ---------
#
#
# Timestep: 2020-02-09 03:45:00
# Price: 0.03472 €/kWh
# SOC: [0.6683137344616534], Time left: [27.25] hours
# Action taken: [0.04885411]
# Actual charging energy: 0.1343488097190857 kWh
# Charging cost/revenue: -0.004664590673446655 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.00932918134689331
# ---------
#
#
# Timestep: 2020-02-09 04:00:00
# Price: 0.0357 €/kWh
# SOC: [0.6701946177977206], Time left: [27.] hours
# Action taken: [0.04338491]
# Actual charging energy: 0.11930850148200989 kWh
# Charging cost/revenue: -0.0042593135029077535 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.008518627005815507
# ---------
#
#
# Timestep: 2020-02-09 04:15:00
# Price: 0.0357 €/kWh
# SOC: [0.6718649368184687], Time left: [26.75] hours
# Action taken: [0.04016209]
# Actual charging energy: 0.11044573783874512 kWh
# Charging cost/revenue: -0.003942912840843201 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.007885825681686403
# ---------
#
#
# Timestep: 2020-02-09 04:30:00
# Price: 0.0357 €/kWh
# SOC: [0.6734111771482111], Time left: [26.5] hours
# Action taken: [0.03699577]
# Actual charging energy: 0.10173836350440979 kWh
# Charging cost/revenue: -0.00363205957710743 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.00726411915421486
# ---------
#
#
# Timestep: 2020-02-09 04:45:00
# Price: 0.0357 €/kWh
# SOC: [0.6748355142372728], Time left: [26.25] hours
# Action taken: [0.03416431]
# Actual charging energy: 0.09395185112953186 kWh
# Charging cost/revenue: -0.0033540810853242876 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.006708162170648575
# ---------
#
#
# Timestep: 2020-02-09 05:00:00
# Price: 0.03835 €/kWh
# SOC: [0.6761508401530862], Time left: [26.] hours
# Action taken: [0.07631648]
# Actual charging energy: 0.20987030863761902 kWh
# Charging cost/revenue: -0.008048526336252691 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.016097052672505382
# ---------
#
#
# Timestep: 2020-02-09 05:15:00
# Price: 0.03835 €/kWh
# SOC: [0.6790890244740129], Time left: [25.75] hours
# Action taken: [0.0731895]
# Actual charging energy: 0.20127111673355103 kWh
# Charging cost/revenue: -0.007718747326731682 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.015437494653463365
# ---------
#
#
# Timestep: 2020-02-09 05:30:00
# Price: 0.03835 €/kWh
# SOC: [0.6819068201082826], Time left: [25.5] hours
# Action taken: [0.07036197]
# Actual charging energy: 0.19349542260169983 kWh
# Charging cost/revenue: -0.007420549456775188 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.014841098913550376
# ---------
#
#
# Timestep: 2020-02-09 05:45:00
# Price: 0.03835 €/kWh
# SOC: [0.6846157560247065], Time left: [25.25] hours
# Action taken: [0.06794047]
# Actual charging energy: 0.18683630228042603 kWh
# Charging cost/revenue: -0.007165172192454338 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.014330344384908676
# ---------
#
#
# Timestep: 2020-02-09 06:00:00
# Price: 0.05013 €/kWh
# SOC: [0.6872314642566324], Time left: [25.] hours
# Action taken: [0.13661397]
# Actual charging energy: 0.3756884038448334 kWh
# Charging cost/revenue: -0.014446884684741496 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.028893769369482993
# ---------
#
#
# Timestep: 2020-02-09 06:15:00
# Price: 0.05013 €/kWh
# SOC: [0.69249110191046], Time left: [24.75] hours
# Action taken: [0.13373506]
# Actual charging energy: 0.3677714169025421 kWh
# Charging cost/revenue: -0.014050006129324435 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.02810001225864887
# ---------
#
#
# Timestep: 2020-02-09 06:30:00
# Price: 0.05013 €/kWh
# SOC: [0.6976399017470957], Time left: [24.5] hours
# Action taken: [0.13116348]
# Actual charging energy: 0.3606995642185211 kWh
# Charging cost/revenue: -0.013695494154274464 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.027390988308548928
# ---------
#
#
# Timestep: 2020-02-09 06:45:00
# Price: 0.05013 €/kWh
# SOC: [0.702689695646155], Time left: [24.25] hours
# Action taken: [0.1289556]
# Actual charging energy: 0.35462790727615356 kWh
# Charging cost/revenue: -0.013391121991753577 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.026782243983507155
# ---------
#
#
# Timestep: 2020-02-09 07:00:00
# Price: 0.062229999999999994 €/kWh
# SOC: [0.7076544863480212], Time left: [24.] hours
# Action taken: [0.13973844]
# Actual charging energy: 0.3842807114124298 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.0
# ---------
#
#
# Timestep: 2020-02-09 07:15:00
# Price: 0.062229999999999994 €/kWh
# SOC: [0.7130344163077952], Time left: [23.75] hours
# Action taken: [0.13784635]
# Actual charging energy: 0.3790774643421173 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.0
# ---------
#
#
# Timestep: 2020-02-09 07:30:00
# Price: 0.062229999999999994 €/kWh
# SOC: [0.7183415008085848], Time left: [23.5] hours
# Action taken: [0.13614643]
# Actual charging energy: 0.3744026720523834 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.0
# ---------
#
#
# Timestep: 2020-02-09 07:45:00
# Price: 0.062229999999999994 €/kWh
# SOC: [0.7235831382173182], Time left: [23.25] hours
# Action taken: [0.13442695]
# Actual charging energy: 0.36967411637306213 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.0
# ---------
#
#
# Timestep: 2020-02-09 08:00:00
# Price: 0.07110999999999999 €/kWh
# SOC: [0.7287585758465411], Time left: [23.] hours
# Action taken: [0.17959356]
# Actual charging energy: 0.49388229846954346 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 6.476964993878166 kW.
# Reward signal: -0.14682876436173117
# ---------
#
#
# Timestep: 2020-02-09 08:15:00
# Price: 0.07110999999999999 €/kWh
# SOC: [0.7356729280251147], Time left: [22.75] hours
# Action taken: [0.17759049]
# Actual charging energy: 0.48837384581565857 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 6.454931183262627 kW.
# Reward signal: -0.1458314780322969
# ---------
#
#
# Timestep: 2020-02-09 08:30:00
# Price: 0.07110999999999999 €/kWh
# SOC: [0.742510161866534], Time left: [22.5] hours
# Action taken: [0.1757567]
# Actual charging energy: 0.4833309054374695 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 6.43475942174987 kW.
# Reward signal: -0.14492145085529556
# ---------
#
#
# Timestep: 2020-02-09 08:45:00
# Price: 0.07110999999999999 €/kWh
# SOC: [0.7492767945426585], Time left: [22.25] hours
# Action taken: [0.17408359]
# Actual charging energy: 0.47872987389564514 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 6.416355295582573 kW.
# Reward signal: -0.1440936534770268
# ---------
#
#
# Timestep: 2020-02-09 09:00:00
# Price: 0.06351 €/kWh
# SOC: [0.7559790127771975], Time left: [22.] hours
# Action taken: [0.16168797]
# Actual charging energy: 0.44464191794395447 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 22.782521271775824 kW.
# Reward signal: -1.8166514642462128
# ---------
#
#
# Timestep: 2020-02-09 09:15:00
# Price: 0.06351 €/kWh
# SOC: [0.7622039996284128], Time left: [21.75] hours
# Action taken: [0.16054595]
# Actual charging energy: 0.44150134921073914 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 22.769958996842963 kW.
# Reward signal: -1.814648614512684
# ---------
#
#
# Timestep: 2020-02-09 09:30:00
# Price: 0.06351 €/kWh
# SOC: [0.7683850185173632], Time left: [21.5] hours
# Action taken: [0.15944588]
# Actual charging energy: 0.43847617506980896 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 22.757858300279242 kW.
# Reward signal: -1.812720400454561
# ---------
#
#
# Timestep: 2020-02-09 09:45:00
# Price: 0.06351 €/kWh
# SOC: [0.7745236849683406], Time left: [21.25] hours
# Action taken: [0.15840626]
# Actual charging energy: 0.43561720848083496 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 22.746422433923346 kW.
# Reward signal: -1.8108990673987195
# ---------
#
#
# Timestep: 2020-02-09 10:00:00
# Price: 0.054509999999999996 €/kWh
# SOC: [0.7806223258870723], Time left: [21.] hours
# Action taken: [0.13466966]
# Actual charging energy: 0.37034156918525696 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 17.672819876741034 kW.
# Reward signal: -1.0931499683850654
# ---------
#
#
# Timestep: 2020-02-09 10:15:00
# Price: 0.054509999999999996 €/kWh
# SOC: [0.7858071078556659], Time left: [20.75] hours
# Action taken: [0.13336086]
# Actual charging energy: 0.3667423725128174 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 17.658423090051276 kW.
# Reward signal: -1.0913696710953962
# ---------
#
#
# Timestep: 2020-02-09 10:30:00
# Price: 0.054509999999999996 €/kWh
# SOC: [0.7909415010708453], Time left: [20.5] hours
# Action taken: [0.13216758]
# Actual charging energy: 0.36346083879470825 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 17.64529695517884 kW.
# Reward signal: -1.0897477662275525
# ---------
#
#
# Timestep: 2020-02-09 10:45:00
# Price: 0.054509999999999996 €/kWh
# SOC: [0.7960299528139712], Time left: [20.25] hours
# Action taken: [0.13105357]
# Actual charging energy: 0.3603973090648651 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 17.633042836259467 kW.
# Reward signal: -1.0882346988287646
# ---------
#
#
# Timestep: 2020-02-09 11:00:00
# Price: 0.0495 €/kWh
# SOC: [0.8010755151408793], Time left: [20.] hours
# Action taken: [0.12653196]
# Actual charging energy: 0.347962886095047 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 17.495805144380192 kW.
# Reward signal: -1.0713611917754213
# ---------
#
#
# Timestep: 2020-02-09 11:15:00
# Price: 0.0495 €/kWh
# SOC: [0.80594699554621], Time left: [19.75] hours
# Action taken: [0.12372243]
# Actual charging energy: 0.34023669362068176 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 17.46490037448273 kW.
# Reward signal: -1.0675796078171247
# ---------
#
#
# Timestep: 2020-02-09 11:30:00
# Price: 0.0495 €/kWh
# SOC: [0.8107103092568995], Time left: [19.5] hours
# Action taken: [0.12110376]
# Actual charging energy: 0.33303534984588623 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 17.43609499938355 kW.
# Reward signal: -1.0640609308963482
# ---------
#
#
# Timestep: 2020-02-09 11:45:00
# Price: 0.0495 €/kWh
# SOC: [0.8153728041547419], Time left: [19.25] hours
# Action taken: [0.11875856]
# Actual charging energy: 0.3265860378742218 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 17.41029775149689 kW.
# Reward signal: -1.060914637285222
# ---------
#
#
# Timestep: 2020-02-09 12:00:00
# Price: 0.04493 €/kWh
# SOC: [0.819945008684981], Time left: [19.] hours
# Action taken: [0.07044315]
# Actual charging energy: 0.19371867179870605 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 6.1386925871948215 kW.
# Reward signal: -0.1318924133802823
# ---------
#
#
# Timestep: 2020-02-09 12:15:00
# Price: 0.04493 €/kWh
# SOC: [0.8226570700901629], Time left: [18.75] hours
# Action taken: [0.06899214]
# Actual charging energy: 0.18972837924957275 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 6.122731416998288 kW.
# Reward signal: -0.13120744001644252
# ---------
#
#
# Timestep: 2020-02-09 12:30:00
# Price: 0.04493 €/kWh
# SOC: [0.8253132673996569], Time left: [18.5] hours
# Action taken: [0.06765437]
# Actual charging energy: 0.18604952096939087 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 6.108015983877561 kW.
# Reward signal: -0.1305775074075632
# ---------
#
#
# Timestep: 2020-02-09 12:45:00
# Price: 0.04493 €/kWh
# SOC: [0.8279179606932284], Time left: [18.25] hours
# Action taken: [0.06654453]
# Actual charging energy: 0.182997465133667 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 6.095807760534665 kW.
# Reward signal: -0.13005605288688127
# ---------
#
#
# Timestep: 2020-02-09 13:00:00
# Price: 0.044109999999999996 €/kWh
# SOC: [0.8304799252050997], Time left: [18.] hours
# Action taken: [0.04401052]
# Actual charging energy: 0.12102892994880676 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 26.913069319795234 kW.
# Reward signal: -2.5350965507423626
# ---------
#
#
# Timestep: 2020-02-09 13:15:00
# Price: 0.044109999999999996 €/kWh
# SOC: [0.832174330224383], Time left: [17.75] hours
# Action taken: [0.04374659]
# Actual charging energy: 0.12030312418937683 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 26.910166096757514 kW.
# Reward signal: -2.5345496377427716
# ---------
#
#
# Timestep: 2020-02-09 13:30:00
# Price: 0.044109999999999996 €/kWh
# SOC: [0.8338585739630343], Time left: [17.5] hours
# Action taken: [0.04364204]
# Actual charging energy: 0.12001562118530273 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 26.909016084741218 kW.
# Reward signal: -2.5343330132710156
# ---------
#
#
# Timestep: 2020-02-09 13:45:00
# Price: 0.044109999999999996 €/kWh
# SOC: [0.8355387926596286], Time left: [17.25] hours
# Action taken: [0.04365838]
# Actual charging energy: 0.12006053328514099 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 26.90919573314057 kW.
# Reward signal: -2.534366852515648
# ---------
#
#
# Timestep: 2020-02-09 14:00:00
# Price: 0.04396 €/kWh
# SOC: [0.8372196401256206], Time left: [17.] hours
# Action taken: [0.01662755]
# Actual charging energy: 0.04572576284408569 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 34.48685665137635 kW.
# Reward signal: -3.0
# ---------
#
#
# Timestep: 2020-02-09 14:15:00
# Price: 0.04396 €/kWh
# SOC: [0.8378598008054378], Time left: [16.75] hours
# Action taken: [0.01632988]
# Actual charging energy: 0.044907182455062866 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 34.48358232982026 kW.
# Reward signal: -3.0
# ---------
#
#
# Timestep: 2020-02-09 14:30:00
# Price: 0.04396 €/kWh
# SOC: [0.8384885013598087], Time left: [16.5] hours
# Action taken: [0.01607525]
# Actual charging energy: 0.04420694708824158 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 34.48078138835297 kW.
# Reward signal: -3.0
# ---------
#
#
# Timestep: 2020-02-09 14:45:00
# Price: 0.04396 €/kWh
# SOC: [0.839107398619044], Time left: [16.25] hours
# Action taken: [0.01584756]
# Actual charging energy: 0.0435808002948761 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 34.47827680117951 kW.
# Reward signal: -3.0
# ---------
#
#
# Timestep: 2020-02-09 15:00:00
# Price: 0.044020000000000004 €/kWh
# SOC: [0.8397175298231723], Time left: [16.] hours
# Action taken: [0.06665564]
# Actual charging energy: 0.18330299854278564 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 42.299665594171145 kW.
# Reward signal: -3.0
# ---------
#
#
# Timestep: 2020-02-09 15:15:00
# Price: 0.044020000000000004 €/kWh
# SOC: [0.8422837718027713], Time left: [15.75] hours
# Action taken: [0.0651046]
# Actual charging energy: 0.1790376603603363 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 42.28260424144135 kW.
# Reward signal: -3.0
# ---------
#
#
# Timestep: 2020-02-09 15:30:00
# Price: 0.044020000000000004 €/kWh
# SOC: [0.844790299047816], Time left: [15.5] hours
# Action taken: [0.06364453]
# Actual charging energy: 0.1750224530696869 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 42.26654341227875 kW.
# Reward signal: -3.0
# ---------
#
#
# Timestep: 2020-02-09 15:45:00
# Price: 0.044020000000000004 €/kWh
# SOC: [0.8472406133907916], Time left: [15.25] hours
# Action taken: [0.06226039]
# Actual charging energy: 0.17121607065200806 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 42.251317882608035 kW.
# Reward signal: -3.0
# ---------
#
#
# Overcharged, penalty of: -0.009322416651880076
# Timestep: 2020-02-09 16:00:00
# Price: 0.04646 €/kWh
# SOC: [0.8496376383799197], Time left: [15.] hours
# Action taken: [0.11959267]
# Actual charging energy: 0.02355350530521938 kWh
# Charging cost/revenue: -0.0010942958564804923 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 44.89447293288575 kW.
# Reward signal: -3.011511008364841
# ---------
#
#
# Overcharged, penalty of: -0.010437317445183256
# Timestep: 2020-02-09 16:15:00
# Price: 0.04646 €/kWh
# SOC: [0.8499673874541928], Time left: [14.75] hours
# Action taken: [0.11825025]
# Actual charging energy: 0.002119815477469311 kWh
# Charging cost/revenue: -9.848662708322419e-05 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 44.8797063589798 kW.
# Reward signal: -3.0106342906993495
# ---------
#
#
# Overcharged, penalty of: -0.010339186805901259
# Timestep: 2020-02-09 16:30:00
# Price: 0.04646 €/kWh
# SOC: [0.8499970648708773], Time left: [14.5] hours
# Action taken: [0.11699522]
# Actual charging energy: 0.00019078339297151636 kWh
# Charging cost/revenue: -8.863796437456651e-06 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 44.865900969575506 kW.
# Reward signal: -3.010356914398776
# ---------
#
#
# Overcharged, penalty of: -0.010142059528451979
# Timestep: 2020-02-09 16:45:00
# Price: 0.04646 €/kWh
# SOC: [0.849999735838379], Time left: [14.25] hours
# Action taken: [0.11581206]
# Actual charging energy: 1.717050536642617e-05 kWh
# Charging cost/revenue: -7.977416793241599e-07 €
# SoH: [1.]
# --------------------------
# Grid connection has been overloaded: 44.8528862953888 kW.
# Reward signal: -3.010143655011811
# ---------
#
#
# Overcharged, penalty of: -0.01957569314045947
# Timestep: 2020-02-09 17:00:00
# Price: 0.05235 €/kWh
# SOC: [0.8499999762254541], Time left: [14.] hours
# Action taken: [0.16088939]
# Actual charging energy: 1.5453454826896973e-06 kWh
# Charging cost/revenue: -8.089883601880566e-08 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.019575854938131507
# ---------
#
#
# Overcharged, penalty of: -0.01908660114008008
# Timestep: 2020-02-09 17:15:00
# Price: 0.05235 €/kWh
# SOC: [0.8499999978602909], Time left: [13.75] hours
# Action taken: [0.15886629]
# Actual charging energy: 1.3908108997817692e-07 kWh
# Charging cost/revenue: -7.2808950603575615e-09 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.019086615701870202
# ---------
#
#
# Overcharged, penalty of: -0.018625424334699443
# Timestep: 2020-02-09 17:30:00
# Price: 0.05235 €/kWh
# SOC: [0.8499999998074261], Time left: [13.5] hours
# Action taken: [0.15693521]
# Actual charging energy: 1.2517299974312834e-08 kWh
# Charging cost/revenue: -6.552806536552768e-10 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.018625425645260752
# ---------
#
#
# Overcharged, penalty of: -0.01818583934960843
# Timestep: 2020-02-09 17:45:00
# Price: 0.05235 €/kWh
# SOC: [0.8499999999826683], Time left: [13.25] hours
# Action taken: [0.15507221]
# Actual charging energy: 1.1265599564325157e-09 kWh
# Charging cost/revenue: -5.89754137192422e-11 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.018185839467559257
# ---------
#
#
# Overcharged, penalty of: -0.021567037096778204
# Timestep: 2020-02-09 18:00:00
# Price: 0.060399999999999995 €/kWh
# SOC: [0.8499999999984401], Time left: [13.] hours
# Action taken: [0.1688739]
# Actual charging energy: 1.0139111772389242e-10 kWh
# Charging cost/revenue: -6.1240235105231026e-12 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.02156703710902625
# ---------
#
#
# Overcharged, penalty of: -0.02121180610471432
# Timestep: 2020-02-09 18:15:00
# Price: 0.060399999999999995 €/kWh
# SOC: [0.8499999999998595], Time left: [12.75] hours
# Action taken: [0.16747737]
# Actual charging energy: 9.12880881998035e-12 kWh
# Charging cost/revenue: -5.513800527268132e-13 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.02121180610581708
# ---------
#
#
# Overcharged, penalty of: -0.020864526078979914
# Timestep: 2020-02-09 18:30:00
# Price: 0.060399999999999995 €/kWh
# SOC: [0.8499999999999873], Time left: [12.5] hours
# Action taken: [0.16610074]
# Actual charging energy: 8.22675261247241e-13 kWh
# Charging cost/revenue: -4.968958577933336e-14 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.020864526079079293
# ---------
#
#
# Overcharged, penalty of: -0.02052150834567138
# Timestep: 2020-02-09 18:45:00
# Price: 0.060399999999999995 €/kWh
# SOC: [0.8499999999999989], Time left: [12.25] hours
# Action taken: [0.16472971]
# Actual charging energy: 7.216449660063518e-14 kWh
# Charging cost/revenue: -4.358735594678364e-15 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.0205215083456801
# ---------
#
#
# Overcharged, penalty of: -0.016998585126287432
# Timestep: 2020-02-09 19:00:00
# Price: 0.06889 €/kWh
# SOC: [0.8499999999999999], Time left: [12.] hours
# Action taken: [0.14992487]
# Actual charging energy: 7.216449660063518e-15 kWh
# Charging cost/revenue: -4.971412170817757e-16 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.016998585126288428
# ---------
#
#
# Overcharged, penalty of: -0.016837909593307023
# Timestep: 2020-02-09 19:15:00
# Price: 0.06889 €/kWh
# SOC: [0.85], Time left: [11.75] hours
# Action taken: [0.14921463]
# Actual charging energy: 0.0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.016837909593307023
# ---------
#
#
# Overcharged, penalty of: -0.016678827110831664
# Timestep: 2020-02-09 19:30:00
# Price: 0.06889 €/kWh
# SOC: [0.85], Time left: [11.5] hours
# Action taken: [0.14850807]
# Actual charging energy: 0.0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.016678827110831664
# ---------
#
#
# Overcharged, penalty of: -0.016487737423041528
# Timestep: 2020-02-09 19:45:00
# Price: 0.06889 €/kWh
# SOC: [0.85], Time left: [11.25] hours
# Action taken: [0.14765489]
# Actual charging energy: 0.0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.016487737423041528
# ---------
#
#
# Overcharged, penalty of: -0.006987589470777156
# Timestep: 2020-02-09 20:00:00
# Price: 0.06605 €/kWh
# SOC: [0.85], Time left: [11.] hours
# Action taken: [0.09612381]
# Actual charging energy: 0.0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.006987589470777156
# ---------
#
#
# Overcharged, penalty of: -0.006899650502314447
# Timestep: 2020-02-09 20:15:00
# Price: 0.06605 €/kWh
# SOC: [0.85], Time left: [10.75] hours
# Action taken: [0.09551704]
# Actual charging energy: 0.0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.006899650502314447
# ---------
#
#
# Overcharged, penalty of: -0.00681163524504882
# Timestep: 2020-02-09 20:30:00
# Price: 0.06605 €/kWh
# SOC: [0.85], Time left: [10.5] hours
# Action taken: [0.09490585]
# Actual charging energy: 0.0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.00681163524504882
# ---------
#
#
# Overcharged, penalty of: -0.006726140318507135
# Timestep: 2020-02-09 20:45:00
# Price: 0.06605 €/kWh
# SOC: [0.85], Time left: [10.25] hours
# Action taken: [0.09430838]
# Actual charging energy: 0.0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -0.006726140318507135
# ---------
#
#
# Overcharged, penalty of: -4.2415337802825805e-05
# Timestep: 2020-02-09 21:00:00
# Price: 0.05546 €/kWh
# SOC: [0.85], Time left: [10.] hours
# Action taken: [0.00748909]
# Actual charging energy: 0.0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -4.2415337802825805e-05
# ---------
#
#
# Overcharged, penalty of: -4.5089312284662954e-05
# Timestep: 2020-02-09 21:15:00
# Price: 0.05546 €/kWh
# SOC: [0.85], Time left: [9.75] hours
# Action taken: [0.00772154]
# Actual charging energy: 0.0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -4.5089312284662954e-05
# ---------
#
#
# Overcharged, penalty of: -4.786653188695311e-05
# Timestep: 2020-02-09 21:30:00
# Price: 0.05546 €/kWh
# SOC: [0.85], Time left: [9.5] hours
# Action taken: [0.00795579]
# Actual charging energy: 0.0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -4.786653188695311e-05
# ---------
#
#
# Overcharged, penalty of: -5.0670645388439794e-05
# Timestep: 2020-02-09 21:45:00
# Price: 0.05546 €/kWh
# SOC: [0.85], Time left: [9.25] hours
# Action taken: [0.00818551]
# Actual charging energy: 0.0 kWh
# Charging cost/revenue: 0.0 €
# SoH: [1.]
# --------------------------
# Reward signal: -5.0670645388439794e-05
# ---------
#
#
# Timestep: 2020-02-09 22:00:00
# Price: 0.04934 €/kWh
# SOC: [0.85], Time left: [9.] hours
# Action taken: [-0.05382293]
# Actual charging energy: -0.14801307022571564 kWh
# Charging cost/revenue: 0.00730296488493681 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.01460592976987362
# ---------
#
#
# Timestep: 2020-02-09 22:15:00
# Price: 0.04934 €/kWh
# SOC: [0.84792781701684], Time left: [8.75] hours
# Action taken: [-0.05379343]
# Actual charging energy: -0.14793193340301514 kWh
# Charging cost/revenue: 0.007298961594104768 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.014597923188209535
# ---------
#
#
# Timestep: 2020-02-09 22:30:00
# Price: 0.04934 €/kWh
# SOC: [0.8458567699491978], Time left: [8.5] hours
# Action taken: [-0.05373931]
# Actual charging energy: -0.147783100605011 kWh
# Charging cost/revenue: 0.007291618183851242 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.014583236367702484
# ---------
#
#
# Timestep: 2020-02-09 22:45:00
# Price: 0.04934 €/kWh
# SOC: [0.8437878065407276], Time left: [8.25] hours
# Action taken: [-0.05363286]
# Actual charging energy: -0.14749035239219666 kWh
# Charging cost/revenue: 0.0072771739870309835 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.014554347974061967
# ---------
#
#
# Timestep: 2020-02-09 23:00:00
# Price: 0.04394 €/kWh
# SOC: [0.8417229416072368], Time left: [8.] hours
# Action taken: [-0.04455781]
# Actual charging energy: -0.12253397703170776 kWh
# Charging cost/revenue: 0.0053841429507732385 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.010768285901546477
# ---------
#
#
# Timestep: 2020-02-09 23:15:00
# Price: 0.04394 €/kWh
# SOC: [0.8400074659287929], Time left: [7.75] hours
# Action taken: [-0.04443836]
# Actual charging energy: -0.12220549583435059 kWh
# Charging cost/revenue: 0.005369709486961365 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.01073941897392273
# ---------
#
#
# Timestep: 2020-02-09 23:30:00
# Price: 0.04394 €/kWh
# SOC: [0.838296588987112], Time left: [7.5] hours
# Action taken: [-0.04428458]
# Actual charging energy: -0.12178260087966919 kWh
# Charging cost/revenue: 0.005351127482652663 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.010702254965305327
# ---------
#
#
# Timestep: 2020-02-09 23:45:00
# Price: 0.04394 €/kWh
# SOC: [0.8365916325747966], Time left: [7.25] hours
# Action taken: [-0.04411376]
# Actual charging energy: -0.12131282687187195 kWh
# Charging cost/revenue: 0.005330485612750053 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.010660971225500106
# ---------
#
#
# Timestep: 2020-02-10 00:00:00
# Price: 0.03209 €/kWh
# SOC: [0.8348932529985904], Time left: [7.] hours
# Action taken: [-0.06327635]
# Actual charging energy: -0.17400996387004852 kWh
# Charging cost/revenue: 0.005583979740589858 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.011167959481179716
# ---------
#
#
# Timestep: 2020-02-10 00:15:00
# Price: 0.03209 €/kWh
# SOC: [0.8324571135044098], Time left: [6.75] hours
# Action taken: [-0.06259531]
# Actual charging energy: -0.1721370965242386 kWh
# Charging cost/revenue: 0.0055238794274628175 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.011047758854925635
# ---------
#
#
# Timestep: 2020-02-10 00:30:00
# Price: 0.03209 €/kWh
# SOC: [0.8300471941530704], Time left: [6.5] hours
# Action taken: [-0.06191629]
# Actual charging energy: -0.17026980221271515 kWh
# Charging cost/revenue: 0.005463957953006029 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.010927915906012059
# ---------
#
#
# Timestep: 2020-02-10 00:45:00
# Price: 0.03209 €/kWh
# SOC: [0.8276634169220923], Time left: [6.25] hours
# Action taken: [-0.06130791]
# Actual charging energy: -0.16859674453735352 kWh
# Charging cost/revenue: 0.005410269532203674 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.010820539064407348
# ---------
#
#
# Timestep: 2020-02-10 01:00:00
# Price: 0.0329 €/kWh
# SOC: [0.8253030624985693], Time left: [6.] hours
# Action taken: [-0.05833554]
# Actual charging energy: -0.16042274236679077 kWh
# Charging cost/revenue: 0.005277908223867416 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.010555816447734833
# ---------
#
#
# Timestep: 2020-02-10 01:15:00
# Price: 0.0329 €/kWh
# SOC: [0.8230571441054343], Time left: [5.75] hours
# Action taken: [-0.05797535]
# Actual charging energy: -0.15943221747875214 kWh
# Charging cost/revenue: 0.0052453199550509455 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.010490639910101891
# ---------
#
#
# Timestep: 2020-02-10 01:30:00
# Price: 0.0329 €/kWh
# SOC: [0.8208250930607318], Time left: [5.5] hours
# Action taken: [-0.05758125]
# Actual charging energy: -0.1583484262228012 kWh
# Charging cost/revenue: 0.00520966322273016 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.01041932644546032
# ---------
#
#
# Timestep: 2020-02-10 01:45:00
# Price: 0.0329 €/kWh
# SOC: [0.8186082150936126], Time left: [5.25] hours
# Action taken: [-0.0572089]
# Actual charging energy: -0.15732446312904358 kWh
# Charging cost/revenue: 0.0051759748369455336 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.010351949673891067
# ---------
#
#
# Timestep: 2020-02-10 02:00:00
# Price: 0.03288 €/kWh
# SOC: [0.816405672609806], Time left: [5.] hours
# Action taken: [-0.06822509]
# Actual charging energy: -0.18761898577213287 kWh
# Charging cost/revenue: 0.006168912252187729 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.012337824504375459
# ---------
#
#
# Timestep: 2020-02-10 02:15:00
# Price: 0.03288 €/kWh
# SOC: [0.8137790068089962], Time left: [4.75] hours
# Action taken: [-0.06764674]
# Actual charging energy: -0.18602854013442993 kWh
# Charging cost/revenue: 0.0061166183996200565 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.012233236799240113
# ---------
#
#
# Timestep: 2020-02-10 02:30:00
# Price: 0.03288 €/kWh
# SOC: [0.8111746072471142], Time left: [4.5] hours
# Action taken: [-0.06707293]
# Actual charging energy: -0.18445055186748505 kWh
# Charging cost/revenue: 0.006064734145402909 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.012129468290805818
# ---------
#
#
# Timestep: 2020-02-10 02:45:00
# Price: 0.03288 €/kWh
# SOC: [0.8085922995209694], Time left: [4.25] hours
# Action taken: [-0.06649601]
# Actual charging energy: -0.18286404013633728 kWh
# Charging cost/revenue: 0.00601256963968277 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.01202513927936554
# ---------
#
#
# Timestep: 2020-02-10 03:00:00
# Price: 0.0329 €/kWh
# SOC: [0.8060322029590608], Time left: [4.] hours
# Action taken: [-0.06868762]
# Actual charging energy: -0.1888909488916397 kWh
# Charging cost/revenue: 0.0062145122185349455 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.012429024437069891
# ---------
#
#
# Timestep: 2020-02-10 03:15:00
# Price: 0.0329 €/kWh
# SOC: [0.8033877296745778], Time left: [3.75] hours
# Action taken: [-0.06791621]
# Actual charging energy: -0.18676958978176117 kWh
# Charging cost/revenue: 0.006144719503819942 €
# SoH: [1.]
# --------------------------
# Reward signal: 0.012289439007639884
# ---------
#
#
# Timestep: 2020-02-10 03:30:00
# Price: 0.0329 €/kWh
# SOC: [0.8007729554176332], Time left: [3.5] hours
# Action taken: [-0.06716138]
# Actual charging energy: -0.18469
